# %%
# importing required modules
from PyPDF2 import PdfReader

from nltk.corpus import wordnet as wn
import nltk 
# nltk.download('wordnet')

part = wn.synsets('body_part')[0]

# https://stackoverflow.com/questions/73117109/how-to-identify-body-part-names-in-a-text-with-python
def is_body_part(candidate):
    for ss in wn.synsets(candidate):
        # only get those where the synset matches exactly
        name = ss.name().split(".", 1)[0]
        if name != candidate:
            continue
        hit = part.lowest_common_hypernyms(ss)
        if hit and hit[0] == part:
            return True
    return False

import os
 
# assign directory
directory = '../Data/scripts/'
 
# iterate over files in
# that directory

files = []
for filename in os.scandir(directory):
    if filename.is_file():
        files.append(filename.path)

# %%
 
# # getting a specific page from the pdf file
# page = reader.pages[0]
 
# # extracting text from page
# text = page.extract_text()

# creating a pdf reader object


 
# printing number of pages in pdf file
# print(len(reader.pages))



for f in files:
    print('\n','---------------------------------',f.split("/")[-1],'----------------------------------','\n')
    reader = PdfReader(f)
    lst=[]
    # len(reader.pages)
    for i in range(0,len(reader.pages)):
        page = reader.pages[i]
        text = page.extract_text()
        lst.append(text)
    #     print(text)
    #     print("-----------------")
    # len(lst[0])

    from nltk.tokenize import word_tokenize

    for i in lst:
        tokens = word_tokenize(i)
    #     for j in i:
    #         tokens = word_tokenize(j) 
    #         print(tokens)
        for k in range(0,len(tokens)):
    #         print(tokens[k].lower())
            if is_body_part(tokens[k].lower()) == True or tokens[k].lower() in ('body','boob','chest','thighs','thigh','waist','breast','ass','lips',
                                                                                'beautiful','attractive','hottie','hot','skirt','beauty','sexy','age',
                                                                                'blond','smile','dumb','cute','perfect','buxom','dress','fit','tight',
                                                                                'blonde','natural','bra','underwear','panty','panties','divine',
                                                                                'curve','curves','trashy','nude','toned','fragile','pretty','womanhood',
                                                                                'breathtaking','fuck me eyes','erotic','lingerie','erotic','glow','gorgeous'
                                                                                ,'figure','fuck-me','fuck me','sexual','pants','shirt','dress','shorts'):
                gram2 = tokens[k-2].lower()
                gram1 = tokens[k-1].lower()
                gram0 = tokens[k].lower()
#                 check = ('his','he','man','men',"man's","men's",'her','she','their','woman','women', "woman's","women's")

                check = ('her','she','their','woman','women', "woman's","women's")
                if gram2 in check or gram1 in check:
                    print(gram2,gram1,gram0)
# Out:
#  --------------------------------- 2001-space-odyssey.php ----------------------------------
#
# on their side
# on their side
# their own side
# from their side
# carry their bone
# woman 's face
# the woman's face
#
#  --------------------------------- avatar.php ----------------------------------
#
# got her arm
# cracking her neck
# she wears shorts
# cracking her neck
# extends her fist
# presses her throat
# in her hand
# . her tail
# at her waist
# grasping her shoulder
# she runs back
# touches her head
# in her eye
# touches her lips
# touches her nose
# of her mouth
# -- her hand
# with her thumb
# on her body
# she steps back
# she pulls back
# on her lips
# rubs her cheek
# she pulls back
# strokes her face
# lays her head
# takes her arm
# takes her finger
# , her face
# down her face
# clutching her stomach
# clutches her abdomen
# crosses her face
# holding her hand
# watches her body
# on her hand
# across her abdomen
# her human body
# on her face
# on her ass
# in her lap
# she glares back
# her other leg
# touches her face
# of her skin
#
#  --------------------------------- avengers-endgame-2019.pdf ----------------------------------
#
# her robotic hand
# past her head
# ruffling her hair
# in their pants
# over her hair
# stuck her hand
# from her neck
# slams her palm
# offers her hand
# from her eye
# lifts her head
# waves her hand
# her “ brain
# of her eye
# lays her hand
# her cybernetic arm
# frying her arm
# her blackened claw
# onto her head
# bring her back
# get her back
# in her arm
# out her hand
# taps her head
# , her face
# strokes her face
# under her arm
# under her arm
# puts her head
# she pulls back
# bring her back
# down her face
# on her toe
#
#  --------------------------------- backtothefuture.pdf ----------------------------------
#
# es her hand
# turns her head
# rolls her eye
# ... their hair
# ; their buxom
# rubbing her head
# over her brain
#
#  --------------------------------- batman-returns.pdf ----------------------------------
#
# across her chest
# with her palm
# over their left
# her surviving heel
# with her hand
# her coat back
# on her shoulder
# , her back
# into her mouth
# bites her finger
# her bandaged hand
# against her forearm
# as her body
# , her hand
# her other hand
# sits her back
# shakes her head
# shooting her paw
# into her mouth
# . her back
# touches her shoulder
# takes her hand
# when their lips
# grabs her heel
# . her body
# above her head
# around her neck
# shakes her head
# hold her tight
# touches her face
# she whips back
# into her arm
# into her leg
# off her hood
# her other leg
# into her mouth
#
#  --------------------------------- batman-returns.txt ----------------------------------
# ---------------------------------------------------------------------------
# PdfReadError                              Traceback (most recent call last)
# Input In [142], in <cell line: 16>()
#      16 for f in files:
#      17     print('\n','---------------------------------',f.split("/")[-1],'----------------------------------','\n')
# ---> 18     reader = PdfReader(f)
#      19     lst=[]
#      20     # len(reader.pages)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\_reader.py:319, in PdfReader.__init__(self, stream, strict, password)
#     317     with open(stream, "rb") as fh:
#     318         stream = BytesIO(fh.read())
# --> 319 self.read(stream)
#     320 self.stream = stream
#     322 self._override_encryption = False
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\_reader.py:1415, in PdfReader.read(self, stream)
#    1413 def read(self, stream: StreamType) -> None:
#    1414     self._basic_validation(stream)
# -> 1415     self._find_eof_marker(stream)
#    1416     startxref = self._find_startxref_pos(stream)
#    1418     # check and eventually correct the startxref only in not strict
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\_reader.py:1471, in PdfReader._find_eof_marker(self, stream)
#    1469 while line[:5] != b"%%EOF":
#    1470     if stream.tell() < last_mb:
# -> 1471         raise PdfReadError("EOF marker not found")
#    1472     line = read_previous_line(stream)
#
# PdfReadError: EOF marker not found

# %%
import re
def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

# files = ['Data/scripts/batmanforever.php']
# Data/scripts/avatar.php','Data/scripts/batmanforever.php'
# 'Data/scripts/backtothefuture.pdf
dic={}
for f in files:
   
    print('\n','---------------------------------',f.split("/")[-1],'----------------------------------','\n')
    reader = PdfReader(f)
    lst=[]
   
    # len(reader.pages)
    for i in range(0,len(reader.pages)):
        page = reader.pages[i]
        text = page.extract_text()
        ls= text.split('\n')
        
        
      
        for j in range(0,len(ls)):
            
            
#             and ls[j].isupper()
# and ls[j].strip()[-1]==':'
        
#             if len(re.findall(r"[\w']+", ls[j].strip()))==1:
            if (len(ls[j].split(" "))==1 or len(ls[j].split(" "))==2) and ls[j].isupper() and '!' not in ls[j] and has_numbers(ls[j])==False:
#                 print(ls[j])
                 
                if j+4 in range(-len(ls), len(ls)):
            
                    if ls[j] not in dic:
                        dic[ls[j].strip()]=ls[j+1]+' '+ls[j+2]+' '+ls[j+3]+' '+ls[j+4]  
                    else:
                        dic[ls[j].strip()]=dic[ls[j]] + ' '+ls[j+1]+' '+ls[j+2]+' '+ls[j+3]+' '+ls[j+4]  
                        
                    
                elif j+3 in range(-len(ls), len(ls)):
        
                    if ls[j] not in dic:
                        dic[ls[j].strip()]=ls[j+1]+' '+ls[j+2]+' '+ls[j+3]
                    else:
                        dic[ls[j].strip()]=dic[ls[j]] + ' '+ls[j+1]+' '+ls[j+2]+' '+ls[j+3]                 
                        

                elif j+2 in range(-len(ls), len(ls)):
                    if ls[j] not in dic:
                        dic[ls[j].strip()]=ls[j+1]+' '+ls[j+2]
                    else:
                        dic[ls[j].strip()]=dic[ls[j]] + ' '+ls[j+1]+' '+ls[j+2]    
                        
                elif j+1 in range(-len(ls), len(ls)):
                    if ls[j] not in dic:
                        dic[ls[j].strip()]=ls[j+1]
                    else:
                        dic[ls[j].strip()]=dic[ls[j]] + ' '+ls[j+1]   
                
            
#             if '(V.O.)' in ls[j]:
#                 if j+4 in range(-len(ls), len(ls)):
#                     dic[ls[j].strip()]=ls[j+1]+' '+ls[j+2]+' '+ls[j+3]+' '+ls[j+4]
#                 elif j+3 in range(-len(ls), len(ls)):
#                     dic[ls[j].strip()]=ls[j+1]+' '+ls[j+2]+' '+ls[j+3]
#                 elif j+2 in range(-len(ls), len(ls)):
#                     dic[ls[j].strip()]=ls[j+1]+' '+ls[j+2]
#                 elif j+1 in range(-len(ls), len(ls)):
#                     dic[ls[j].strip()]=ls[j+1]
# Out:
#  --------------------------------- 2001-space-odyssey.php ----------------------------------
#
#
#  --------------------------------- avatar.php ----------------------------------
#
#
#  --------------------------------- avengers-endgame-2019.pdf ----------------------------------
#
#
#  --------------------------------- backtothefuture.pdf ----------------------------------
#
#
#  --------------------------------- batman-returns.pdf ----------------------------------
#
#
#  --------------------------------- batman1989.php ----------------------------------
#
#
#  --------------------------------- batmanforever.php ----------------------------------
#
#
#  --------------------------------- beverly-hills-copII.pdf ----------------------------------
#
#
#  --------------------------------- BlackPanther.pdf ----------------------------------
#
#
#  --------------------------------- Blazing-Saddles (1).pdf ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 9>()
#      16     for i in range(0,len(reader.pages)):
#      17         page = reader.pages[i]
# ---> 18         text = page.extract_text()
#      19         ls= text.split('\n')
#      23         for j in range(0,len(ls)):
#      24
#      25
#    (...)
#      28
#      29 #             if len(re.findall(r"[\w']+", ls[j].strip()))==1:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\_page.py:1851, in PageObject.extract_text(self, Tj_sep, TJ_sep, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, *args)
#    1848 if isinstance(orientations, int):
#    1849     orientations = (orientations,)
# -> 1851 return self._extract_text(
#    1852     self,
#    1853     self.pdf,
#    1854     orientations,
#    1855     space_width,
#    1856     PG.CONTENTS,
#    1857     visitor_operand_before,
#    1858     visitor_operand_after,
#    1859     visitor_text,
#    1860 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\_page.py:1356, in PageObject._extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    1352     content = (
#    1353         obj[content_key].get_object() if isinstance(content_key, str) else obj
#    1354     )
#    1355     if not isinstance(content, ContentStream):
# -> 1356         content = ContentStream(content, pdf, "bytes")
#    1357 except KeyError:  # it means no content can be extracted(certainly empty page)
#    1358     return ""
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\generic\_data_structures.py:872, in ContentStream.__init__(self, stream, pdf, forced_encoding)
#     870     stream_bytes = BytesIO(data)
#     871 else:
# --> 872     stream_data = stream.get_data()
#     873     assert stream_data is not None
#     874     stream_data_bytes = b_(stream_data)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\generic\_data_structures.py:827, in EncodedStreamObject.get_data(self)
#     823 else:
#     824     # create decoded object
#     825     decoded = DecodedStreamObject()
# --> 827     decoded._data = decode_stream_data(self)
#     828     for key, value in list(self.items()):
#     829         if key not in (SA.LENGTH, SA.FILTER, SA.DECODE_PARMS):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\filters.py:525, in decode_stream_data(stream)
#     523 for filter_type in filters:
#     524     if filter_type in (FT.FLATE_DECODE, FTA.FL):
# --> 525         data = FlateDecode.decode(data, stream.get(SA.DECODE_PARMS))
#     526     elif filter_type in (FT.ASCII_HEX_DECODE, FTA.AHx):
#     527         data = ASCIIHexDecode.decode(data)  # type: ignore
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\filters.py:98, in FlateDecode.decode(data, decode_parms, **kwargs)
#      96     deprecate_with_replacement("decodeParms", "parameters", "4.0.0")
#      97     decode_parms = kwargs["decodeParms"]
# ---> 98 str_data = decompress(data)
#      99 predictor = 1
#     101 if decode_parms:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\filters.py:66, in decompress(data)
#      64 def decompress(data: bytes) -> bytes:
#      65     try:
# ---> 66         return zlib.decompress(data)
#      67     except zlib.error:
#      68         d = zlib.decompressobj(zlib.MAX_WBITS | 32)
#
# KeyboardInterrupt:

# %%
for key, value in dic.items() :
    print (key,len(value))

# %%
# importing required modules
from PyPDF2 import PdfReader

from nltk.corpus import wordnet as wn
import nltk 
# nltk.download('wordnet')

part = wn.synsets('body_part')[0]

# https://stackoverflow.com/questions/73117109/how-to-identify-body-part-names-in-a-text-with-python
def is_body_part(candidate):
    for ss in wn.synsets(candidate):
        # only get those where the synset matches exactly
        name = ss.name().split(".", 1)[0]
        if name != candidate:
            continue
        hit = part.lowest_common_hypernyms(ss)
        if hit and hit[0] == part:
            return True
    return False

import os
 
# assign directory
directory = '../Data/scripts/'
 
# iterate over files in
# that directory

files = []
for filename in os.scandir(directory):
    if filename.is_file():
        files.append(filename.path)

# %%
 
# # # getting a specific page from the pdf file
# # page = reader.pages[0]
 
# # # extracting text from page
# # text = page.extract_text()

# # creating a pdf reader object


 
# # printing number of pages in pdf file
# # print(len(reader.pages))



# for f in files:
#     print('\n','---------------------------------',f.split("/")[-1],'----------------------------------','\n')
#     reader = PdfReader(f)
#     lst=[]
#     # len(reader.pages)
#     for i in range(0,len(reader.pages)):
#         page = reader.pages[i]
#         text = page.extract_text()
#         lst.append(text)
#     #     print(text)
#     #     print("-----------------")
#     # len(lst[0])

#     from nltk.tokenize import word_tokenize

#     for i in lst:
#         tokens = word_tokenize(i)
#     #     for j in i:
#     #         tokens = word_tokenize(j) 
#     #         print(tokens)
#         for k in range(0,len(tokens)):
#     #         print(tokens[k].lower())
#             if is_body_part(tokens[k].lower()) == True or tokens[k].lower() in ('body','boob','chest','thighs','thigh','waist','breast','ass','lips',
#                                                                                 'beautiful','attractive','hottie','hot','skirt','beauty','sexy','age',
#                                                                                 'blond','smile','dumb','cute','perfect','buxom','dress','fit','tight',
#                                                                                 'blonde','natural','bra','underwear','panty','panties','divine',
#                                                                                 'curve','curves','trashy','nude','toned','fragile','pretty','womanhood',
#                                                                                 'breathtaking','fuck me eyes','erotic','lingerie','erotic','glow','gorgeous'
#                                                                                 ,'figure','fuck-me','fuck me','sexual','pants','shirt','dress','shorts'):
#                 gram2 = tokens[k-2].lower()
#                 gram1 = tokens[k-1].lower()
#                 gram0 = tokens[k].lower()
# #                 check = ('his','he','man','men',"man's","men's",'her','she','their','woman','women', "woman's","women's")

#                 check = ('her','she','their','woman','women', "woman's","women's")
#                 if gram2 in check or gram1 in check:
#                     print(gram2,gram1,gram0)

# %%
import re

def checkUpper(s):
    if len(s)>1 and s.isupper()!=True:
        if ":" in e:
            return False
        else:
            return True
    elif len(s)==1 or len(s)==0:
        return True
    else:
        return False

def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

files = ['../Data/scripts/song-of-the-south.php']
# Data/scripts/avatar.php','Data/scripts/batmanforever.php'
# 'Data/scripts/backtothefuture.pdf
dic={}
# Maindic={}
for f in files:
    dic={}
    title = f.split("/")[-1]
    print('\n','---------------------------------',title,'----------------------------------','\n')
    reader = PdfReader(f)
    lst=[]
   
    # len(reader.pages)
    for i in range(0,len(reader.pages)):
        
        
        
            
        
        page = reader.pages[i]
        text = page.extract_text()
        ls= text.split('\n')
        
        
      
      
        for j in range(0,len(ls)):

            
            cleaned = ls[j].strip()
            
            print(cleaned.split(" "))
            if (len(cleaned.split(" "))==1 or len(cleaned.split(" "))==2) and (cleaned.isupper() or ":" in cleaned) and '!' not in cleaned and has_numbers(cleaned)==False:
                
                if j+6 in range(-len(ls), len(ls)):
                    
                    word = ls[j+1].strip()+' '+ls[j+2].strip()+' '+ls[j+3].strip()+' '+ls[j+4].strip()+ ' '+ls[j+5].strip()+ ' '+ls[j+6].strip() 
                    
                    newword=[]
#                     print(cleaned)
#                     print(ls[j])
#                     if ls[j].strip()=='POLICE OFFICER':
#                         print(word.split(' '))
                    for e in word.split(' '):
                        
                        if checkUpper(e):
                            newword.append(e)
                        else:
                            break
#                     print(newword)

                    word = ' '.join(newword)
                    
                    
                    if ls[j] not in dic:
                        
                        dic[ls[j].strip()]= word
                        
                    else:
                        dic[ls[j].strip()]=dic[ls[j]] + ' '+word
                        
                    
                elif j+5 in range(-len(ls), len(ls)):
                    
                    word = ls[j+1].strip()+' '+ls[j+2].strip()+' '+ls[j+3].strip()+' '+ls[j+4].strip()+ ' '+ls[j+5].strip()
                    newword=[]

                    for e in word.split(' '):
                        
                        if checkUpper(e):
                            newword.append(e)
                        else:
                            break

                    word = ' '.join(newword)
                    
                    if ls[j] not in dic:
                        
                        dic[ls[j].strip()]= word
                        
                    else:
                        dic[ls[j].strip()]=dic[ls[j]] + ' '+word         
                        

                elif j+4 in range(-len(ls), len(ls)):
                    word = ls[j+1].strip()+' '+ls[j+2].strip()+' '+ls[j+3].strip()+' '+ls[j+4].strip()
                    newword=[]

                    for e in word.split(' '):
                        
                        if checkUpper(e):
                            newword.append(e)
                        else:
                            break

                    word = ' '.join(newword)
                    
                    if ls[j] not in dic:
                        
                        dic[ls[j].strip()]= word
                        
                    else:
                        dic[ls[j].strip()]=dic[ls[j]] + ' '+word
                        
                        
#                 Doing for 3 lines because the above code already caters to the lines that already exist 

                elif j+3 in range(-len(ls), len(ls)):
                    word = ls[j+1].strip()+' '+ls[j+2].strip()+' '+ls[j+3].strip()
                    newword=[]

                    for e in word.split(' '):
                        
                        if checkUpper(e):
                            newword.append(e)
                        else:
                            break

                    word = ' '.join(newword)
                    
                    if ls[j] not in dic:
                        
                        dic[ls[j].strip()]= word
                        
                    else:
                        dic[ls[j].strip()]=dic[ls[j]] + ' '+word
                        
          
                        
#         Maindic[title] = dic
                
            
#             if '(V.O.)' in ls[j]:
#                 if j+4 in range(-len(ls), len(ls)):
#                     dic[ls[j].strip()]=ls[j+1]+' '+ls[j+2]+' '+ls[j+3]+' '+ls[j+4]
#                 elif j+3 in range(-len(ls), len(ls)):
#                     dic[ls[j].strip()]=ls[j+1]+' '+ls[j+2]+' '+ls[j+3]
#                 elif j+2 in range(-len(ls), len(ls)):
#                     dic[ls[j].strip()]=ls[j+1]+' '+ls[j+2]
#                 elif j+1 in range(-len(ls), len(ls)):
#                     dic[ls[j].strip()]=ls[j+1]
                
                     
# Maindic
dic
# Out:
#  --------------------------------- song-of-the-south.php ----------------------------------
#
# ['Scripts.com']
# ['Song', 'of', 'the', 'South']
# ['By', 'Dalton', 'S.', 'Reymond']
# ['Page', '1/64']
# ['Music', 'Chorus:']
# ['music', 'weaves', 'a', 'magic', 'spell...']
# ['Music', 'Chorus:']
# ['I', 'see', 'the', 'scenes', 'I', 'know', 'so', 'well...']
# ['Music', 'Chorus:']
# ['cabin', 'door.', 'Pale', 'moon', 'light', 'on', 'a', 'field', 'of', 'white...']
# ['Music', 'Chorus:']
# ['Music', 'Solo:']
# ['voices', 'calling', 'low.', 'Out', 'of', 'the', 'long,', 'long', 'ago.']
# ['Music', 'Chorus:']
# ["That's", 'where', 'I', 'belong.', "Singin'", 'a', 'song,', 'a', 'Song', 'of', 'the', 'South']
# ['Remus:']
# ["'bout", 'de', 'behind', 'feet', 'of', 'a', 'mule', 'den', "gettin'", 'kicked', 'by', "'em."]
# ['Remus:']
# ['yer', 'tales', "'bout", 'critters', 'like', 'Brer', 'Rabbit,', "an'", 'Brer', 'Fox...']
# ['Remus:']
# ['same', 'like', 'kin', 'happen', 'to', 'folks...']
# ['Remus:']
# ["jes'", "ain't", 'got', 'dey', 'ears', 'tuned', 'fer', "lis'nin."]
# ['Remus:']
# ['all', 'mixt', 'up', 'wid', 'dey', 'own', 'troubles,', 'uh...']
# ['Remus:']
# ['was', "comin'", 'down', 'to', 'de', 'plantation.']
# ['Johnny:']
# ['Sally:']
# ['Johnny:']
# ['Sally:']
# ['Page', '2/64']
# ['Johnny:']
# ['like', 'she', 'did', 'last', 'spring?']
# ['Sally:']
# ["you'd", 'enjoy', 'seeing', 'the', 'plantation.']
# ['Johnny:']
# ['Sally:']
# ['What', 'ever', 'gave', 'you', 'that', 'idea?']
# ['Johnny:']
# ['at', 'what', 'Daddy', 'writes', 'in', 'the', 'newspaper.']
# ['Johnny:']
# ["Don't", 'she?']
# ['John:']
# ['Sally:']
# ['Johnny:']
# ['Sally:']
# ['Tempy:']
# ['Lissen!']
# ['Tempy:']
# ['frogs', 'like', 'dem', 'in', 'Atlanta.']
# ['John:']
# ['John:']
# ['Johnny:']
# ['John:']
# ['Johnny:']
# ['John:']
# ['I', 'used', 'to', 'catch', 'lots', 'of', "'em."]
# ['Page', '3/64']
# ['John:']
# ["'em", 'over', 'in', 'your', "grandma's", 'milk', 'house']
# ['John:']
# ['Tempy:']
# ['you', 'got', 'for', "doin'", 'it', 'too.']
# ['John:']
# ['He', 'told', 'me', 'that', 'story', 'about', 'Brer', 'Frog.']
# ['Tempy:']
# ['John:']
# ['How', 'can', 'there', 'be', 'a', 'tale...']
# ['Tempy', 'and', 'John:']
# ['Johnny:']
# ['Tempy:']
# ['Johnny:']
# ['Tempy:']
# ['him', 'tell', 'a', 'tale', "'bout", 'Brer', 'Rabbit.']
# ['Tempy:']
# ['Doshy:']
# ['Doshy:']
# ['the', 'house', 'again.', 'Turn', 'around', 'here,', 'young', 'man.']
# ['Doshy:']
# ['grandfather', 'more', 'every', 'time', 'I', 'see', 'you.', 'Toby!']
# ['Toby:']
# ['Doshy:']
# ['And', "he's", 'the', 'apple', 'of', 'my', 'eye.']
# ['Doshy:']
# ['of', 'him', 'and', 'show', 'him', 'our', 'plantation.']
# ['Page', '4/64']
# ['Doshy:']
# ['you', 'see', 'that', 'he', 'gets', 'out', 'of', 'it.']
# ['Toby:']
# ['Doshy:']
# ['Doshy:']
# ['and', 'what', "they're", 'up', 'to.']
# ['Johnny:']
# ['Tempy:']
# ["Dat's", "jes'", 'Ned.']
# ['Toby:']
# ['Doshy:']
# ['clatter', "you've", 'raised', 'in', 'Atlanta.']
# ['Doshy:']
# ['and...', 'heaven', 'knows', 'what.']
# ['Ned:']
# ['Where', 'do', 'you', 'want', 'me', 'to', 'put', 'dishyer', 'trunk?']
# ['Doshy:']
# ['Perhaps', "I'd", 'better', 'show', 'him', 'myself.', 'Come', 'along.']
# ['Doshy:']
# ['John:']
# ['John:']
# ['Have', 'you', 'changed', 'your', 'mind,']
# ['John:']
# ['Sally:']
# ['It', "wouldn't", 'be', 'fair', 'to', 'mama.']
# ['Sally:']
# ["I'm", 'not', 'going', 'to', 'saddle', 'her', 'with', 'ours.']
# ['Page', '5/64']
# ['John:']
# ["She's", 'be', 'only', 'too', 'glad', 'to', 'take', 'care', 'of', 'Johnny.']
# ['Toby:']
# ['watch', 'out!']
# ['Toby:']
# ['John:']
# ['here', 'for', 'awhile...', 'with', 'you.']
# ['Doshy:']
# ['John:']
# ['And', 'I', 'want', 'Sally', 'to', 'go', 'with', 'me.']
# ['Sally:']
# ["I'm", 'not', 'going', 'back.']
# ['John:']
# ['And', "I'd", 'better', 'hurry,', 'or', "I'll", 'miss', 'my', 'train.']
# ['Doshy:']
# ['Johnny:']
# ['John:']
# ['Johnny:']
# ['John:']
# ['Johnny:']
# ['John:']
# ['to', 'do,', 'and', "you've", 'got', 'one', 'too.']
# ['John:']
# ["You'll", 'do', 'that', 'now', 'for', 'me,', "won't", 'you?']
# ['John:']
# ['John:']
# ['Page', '6/64']
# ['Doshy:']
# ['John:']
# ['Sally:']
# ['Johnny:']
# ['Please!', 'I', "won't", 'stay', 'here!']
# ['Johnny:']
# ['Johnny', 'Crying']
# ['Music', 'Chorus:']
# ['Music', 'Chorus:']
# ["That's", 'how', 'the', 'critters', 'got', 'that', 'way.']
# ['Music', 'Solo:']
# ['from', "eatin'", 'too', 'much', 'speckle', 'trout.']
# ['Music', 'Solo:']
# ['Chorus:']
# ['Music', 'Chorus:']
# ["That's", 'what', 'Uncle', 'Remus', 'said.']
# ['Music', 'Chorus:']
# ['Solo:']
# ['Music', 'Chorus:']
# ['Solo:']
# ['Music', 'Solo:']
# ['His', 'bed', 'was', 'full', 'of', 'sandy', 'lumps,']
# ['Music', 'Solo:']
# ['Music', 'Chorus:']
# ["that's", 'what', 'Uncle', 'Remus', 'said.']
# ['Page', '7/64']
# ['Music', 'Chorus:']
# ['Solo:']
# ['Music', 'Chorus:']
# ['Solo:']
# ['Music', 'Solo:']
# ['He', 'tried', 'the', 'same', 'thing', 'on', 'a', 'rail.']
# ['Music', 'Solo:']
# ['Remus:']
# ["sho's", "I'm", 'named', 'Remus.']
# ['Remus:']
# ['dat', 'dey', "ain't", 'nobody', 'kin', 'out-do', "'im,"]
# ['Remus:']
# ['Remus:']
# ['sez', 'Brer', 'Fox,', 'sez', 'he.']
# ['Remus:']
# ['Well', 'den,', 'sez', 'Brer', 'Fox,', 'sez', 'he...']
# ['Remus:']
# ['And', 'wid', 'dat', 'he', 'grab', 'Brer', 'Rabbit']
# ['Remus:']
# ["agin'", 'de', "groun'.", 'But', "jes'", 'den,']
# ['Remus:']
# ["an'", 'he', 'tuck', 'thru', 'the', 'cotton', 'patch']
# ['Remus:']
# ["An'", 'from', 'dat', 'day', 'to', 'dis,']
# ['Remus:']
# ['was', 'a', "lil'", "ol'", 'ball', "o'", 'cotton.']
# ['Pearl:']
# ['Page', '8/64']
# ['Remus:']
# ['much', 'cloth', 'for', 'to', 'cut', 'one', 'pair', 'of', 'pants.']
# ['Toby:']
# ['de', 'whole', 'United', 'States', "o'", 'Georgia!']
# ['Remus:']
# ['tell', "'em", 'when', 'I', 'could', 'tell', "'em."]
# ['Remus:']
# ['buttons', "off'n", "yo'", 'what-cher', 'macollums.']
# ['Remus:']
# ['sit', "jes'", 'as', "you's", 'a', "settin'", 'right', 'now']
# ['Remus:']
# ['Chloe:']
# ['Lawzy', 'mursy,', 'have', 'you', 'seen', 'Johnny?']
# ['Chloe:']
# ['high', 'and', 'low', 'for', 'dat', 'child!']
# ['Tempy:']
# ["lis'nin", 'to', 'one', "'o", "yo'", 'tales?']
# ['Toby:']
# ['Chloe:']
# ["Didn't", 'Miss', 'Doshy', 'tell', 'you', 'to', 'take', 'care', "'o", 'him?']
# ['Tempe:']
# ['Miss', 'Sally', 'go', 'outer', 'her', "min'."]
# ['Remus:']
# ['You', 'tell', 'Miss', 'Sally', 'de', "boy's", 'wid', 'me.']
# ['Tempy:']
# ['Remus:']
# ['Tempy:']
# ['Remus:']
# ['Page', '9/64']
# ['done', 'gone', 'and', 'got', "sum'n", 'in', "yo'", 'eye.']
# ['Remus:']
# ["blowin'", "'round", 'here', 'de', 'way', 'de', 'does.']
# ['Remus:']
# ["you's", "figgerin'", 'on', "goin'", 'some', 'place.']
# ['Johnny:']
# ['Remus:']
# ['You', 'know,', 'I', 'was', "jes'", "figgerin'", 'on', "doin'", "sump'n"]
# ['Remus:']
# ['Uncle', 'Remus', 'to', 'go', 'long', 'wid', 'you?']
# ['Remus:']
# ['How', 'kin', 'we', 'be', "goin'", 'sum', 'place', 'if', 'we', 'dunno', 'whar', "we's", 'goin?']
# ['Johnny:']
# ['Remus:']
# ['Is', 'you', 'brung', 'some', 'grub?']
# ['Johnny:']
# ['Remus:']
# ['we', 'sho', "can't", 'get', 'very', 'fur.']
# ['Remus:']
# ['some', 'cawn-bread?', "An'", 'mebbe', 'some', 'sweet', 'tatters?']
# ['Remus:']
# ['I', 'need', 'young', 'eyes', 'in', 'de', 'dark.']
# ['Remus:']
# ['on', 'sech', 'a', 'long', 'trip,', "ain't", 'it?']
# ['Johnny:']
# ['Just', "'cause", 'you', 'said', 'you', 'would.']
# ['Remus:']
# ["nuthin'", "'bout", 'not', "goin'.", "Co'se", "I'll", 'go.']
# ['Page', '10/64']
# ['Johnny:']
# ['Johnny:']
# ['Remus:']
# ['Remus:']
# ['the', 'words', 'that', "ol'", 'Brer', 'Rabbit', 'used']
# ['Remus:']
# ["An'", 'I', "ain't", 'never', "comin'", 'back,', 'neither!']
# ['Remus:']
# ['Remus:']
# ['things', 'together', "so's", 'we', 'can', 'be', "leavin'."]
# ['Johnny:']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ['Remus:']
# ['but', 'it', 'done', 'gone', 'clean', 'off', 'my', 'mind.']
# ['Johnny:']
# ['Brer', 'Rabbit', 'not', 'coming', 'back', 'to', 'his', 'briar', 'patch.']
# ['Remus:']
# ['And', 'if', 'I', "don't", 'tell', 'you', 'about', "'im,", "you're", 'gonna']
# ['Remus:']
# ["'Tain't", 'no', 'great', 'tale,', 'no-how.']
# ['Johnny:']
# ['that', 'got', 'away', 'from', 'the', 'fox?']
# ['Remus:']
# ['Brer', 'Rabbit.', 'Now', 'you', "jes'", 'set', "yo'se'f", 'down', 'here']
# ['Remus:']
# ['Page', '11/64']
# ["'cause", 'dishyer', 'Brer', 'Rabbit,', "he's", 'de', "out-doin'est,"]
# ['Remus:']
# ['Now', 'dishyer', 'tale', "didn't", 'happen', "jes'", 'yestiddy...']
# ['Remus:']
# ["An'", 'in', 'dem', 'days,', "eve'thing", 'was', 'mighty', 'satisfactual.']
# ['Remus:']
# ["an'", 'de', 'folks,', 'dey', 'was', 'closer', 'to', 'de', 'critters...']
# ['Remus:']
# ["t'was", 'better', 'all', 'around.']
# ['Remus:']
# ['Zip-a-dee-do-da', 'days.']
# ['Remus:']
# ['open', 'your', 'mouth', 'without', 'a', 'song', 'jump', 'right', 'out', 'of', 'it...']
# ['Music', 'Remus:']
# ['my', 'oh', 'my,', 'what', 'a', 'wonderful', 'day.']
# ['Music', 'Remus:']
# ['my', 'way.', 'Zip-a-dee-do-da,', 'zip-a-dee-ay.']
# ['Music', 'Remus:']
# ["It's", 'de', 'truff,', "it's", 'actual,', 'everything', 'is', 'satisfactual.']
# ['Music', 'Remus:']
# ['wonderful', 'feeling,', 'wonderful', 'day.', 'Yass', 'suh!']
# ['Music', 'Remus:']
# ['my', 'oh', 'my', 'what', 'a', 'wonderful', 'day.']
# ['Music', 'Moles:']
# ['Zip-a-dee-do-da,', 'zip-a-dee-ay.']
# ['Music', 'Remus:']
# ["It's", 'de', 'truff,', "it's", 'actual,', 'everything', 'is', 'satisfactual.']
# ['Music', 'Remus:']
# ['wonderful', 'feeling,', 'feeling', 'this', 'way.']
# ['Page', '12/64']
# ['Music', 'Remus:']
# ['zum,', 'zum,', 'zum,', 'zum,', 'zum,', 'zum', 'zum.']
# ['Music', 'Remus:']
# ['bum,', 'bum,', 'bum,', 'boo', 'boo', 'Boo']
# ['Music', 'Remus:']
# ["It's", 'de', 'truff,', "it's", 'actual...']
# ['Remus:']
# ['Bluebird:']
# ['Music', 'Remus:']
# ['Music', 'Remus:']
# ['wonderful', 'feeling,', 'wonderful', 'da...', 'hammering', 'noise']
# ['Rabbit:']
# ['ol', 'place', 'like', 'this!', 'Doggone..', 'Keep', 'on...']
# ['Remus:']
# ['Rabbit:']
# ['Oh-ah-uh-uh-ah-hello', 'Uncle', 'Remus.']
# ['Remus:']
# ['bad', 'mood', 'to', 'go', 'to', 'de', 'party.']
# ['Rabbit:']
# ["goin'", 'to', 'be', 'here.', "I'm", "goin'", 'leave', 'this', "'ol", 'place.']
# ['Remus:']
# ['Rabbit:']
# ['Remus:']
# ['Rabbit:']
# ['Remus:']
# ['Rabbit:']
# ['Dat', "ol'", 'briar', 'patch', "ain't", 'brought', 'me', "nothin'", 'but', 'trouble.']
# ['Page', '13/64']
# ['Rabbit:']
# ['Rabbit:']
# ["an'", 'dis', 'de', 'place', 'i', 'belongs', 'away', 'from.']
# ['Remus:']
# ['Rabbit:']
# ['there', "ain't", 'gonna', 'be', 'no', 'trouble.']
# ['Remus:']
# ['Rabbit:']
# ['up', 'my', 'mind,', 'an', 'I', "ain't", 'never', "comin'", 'back.']
# ['Rabbit:']
# ['Remus:']
# ['Rabbit:']
# ['ah', 'can', 'take', 'care', "o'", 'myself.']
# ['Rabbit', 'whistles', 'as', 'he', 'hops', 'away', 'down', 'the', 'path']
# ['Remus:']
# ['but,', 'he', 'was', "headin'", 'straight', 'for', 'a', 'whole']
# ['Remus:']
# ['Rabbit:']
# ['Cowbel', 'jingles', 'as', 'rabbit', 'bounces']
# ['Remus:']
# ["'twixt", 'de', 'heavens', 'and', 'de', 'earth...']
# ['Remus:']
# ['den', 'he', 'scared', 'he', "ain't", "goin'", 'fall...']
# ['Remus:']
# ['heaved', 'and', 'he', 'hauled.', 'But', "warn't", 'no', 'use.']
# ['Remus:']
# ['all', 'right,', "an'", 'he', 'sorta', 'specks', 'he', 'knows', 'who']
# ['Page', '14/64']
# ['Remus:']
# ['up', 'on', 'chickapin', 'hill,', 'where', 'he', 'live...']
# ['Remus:']
# ["ol'", 'Brer', 'Fox,', 'and', 'when', 'dat', "ol'", 'scamp', 'see']
# ['Remus:']
# ['Fox:']
# ['Fox:']
# ['rabbit', 'dis', 'time', "fo'", "sho'.", 'Heh', 'heh', 'heh!']
# ['Remus:']
# ['make', 'ready', 'for', 'to', 'settle', 'Brer', "Rabbit's", 'hash,', 'right', 'now.']
# ['Remus:']
# ['without', 'much', 'strength,', "he's", 'supposed', 'to', 'use', 'his']
# ['Remus:']
# ['sackly', 'what', 'he', 'starting', 'to', 'do,', 'when', 'he', 'hear', 'ole']
# ['Remus:']
# ['Bear:']
# ['Zip-da-da-da-da,', 'wonderful', 'day.', 'Zip-a-da-de-da...']
# ['Rabbit:']
# ['Bear:']
# ['Rabbit:']
# ['Bear:']
# ['Rabbit:']
# ["I'se", "makin'", 'a', 'dollar', 'a', 'minute.']
# ['Bear:']
# ['Rabbit:']
# ['Rabbit:']
# ['Page', '15/64']
# ['Bear:']
# ['Rabbit:']
# ['mighty', 'fine', 'scarecrow,', 'brother', 'Bear.']
# ['Bear:']
# ['Rabbit:']
# ['Bear:']
# ['Rabbit:']
# ['Rabbit:']
# ['enough', 'money!', 'I', 'gots', 'all', 'I', 'wants.']
# ['Rabbit:']
# ['Bear:']
# ['Bear:']
# ['Rabbit:']
# ['Bear:']
# ['Rabbit:']
# ['Bear:']
# ['Rabbit:']
# ['Bear:']
# ['Rabbit:']
# ['Rabbit:']
# ['Bear:']
# ['Bear:']
# ['Rabbit:']
# ['Page', '16/64']
# ['Rabbit:']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['Bear:']
# ['Bear:']
# ['Fox:']
# ['Fox:']
# ['Bear:']
# ['Rabbit:']
# ['Clip', "'im", 'in', 'the', 'head,', 'Brother', 'Bear.']
# ['Fox:']
# ['See', 'there?']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['Bear:']
# ['Page', '17/64']
# ['Fox:']
# ['Fox:']
# ["He's", 'mine', 'look', 'out', 'dar']
# ['Fox:']
# ['Bear:']
# ['Remus:']
# ['hand', 'and', 'put', 'out', 'for', 'home..', 'where', 'he', "b'long."]
# ['Remus:']
# ['place,', 'you', "can't", 'run', 'away', 'from', 'trouble.']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ["sayin'", 'dat', 'he', 'run', 'as', 'fast', 'as', 'he', 'kin.']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ["can't", 'zackly', 'say,', "'cause", 'I', "ain't", 'been', 'keepin', 'close']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ['use', "o'", "speculatin'", 'on', 'dat..', 'when', "we's", "goin'", 'away?']
# ['Johnny:']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ["What's", 'done', 'come', 'over', 'you,', 'honey?']
# ['Page', '18/64']
# ['Johnny:']
# ['Remus:']
# ['Tch', 'Tch..!', "An'", 'jes', 'when', 'I', 'had', 'a', "hankerin'", 'for', 'to', 'go.']
# ['Johnny:']
# ['Remus:']
# ['I', 'kin', 'give', 'it', 'up', 'if', 'you', 'kin.']
# ['Toby:']
# ['no', 'place.', "An'", "I'se", "s'posed", 'to', 'take', 'keer', "o'him."]
# ['Remus:']
# ['Toby:']
# ['Toby:']
# ['fell', 'in', 'de', 'mill', "pon'..", 'He', 'mighter', 'got', 'et', 'up.']
# ['Toby:']
# ['else!', 'How', 'you', 'like', 'dat,', "Unc'", 'Remus!', "It's", 'Him.']
# ['Remus:']
# ['Toby:']
# ['Remus:']
# ['Toby:']
# ['Toby:']
# ['Johnny:']
# ['my', 'hand,', 'Uncle', 'Remus,', "an'", 'git', 'a-goin.']
# ['Remus:']
# ['let', "ol'", "Unc'", 'Remus', 'go', "'long", 'wid', 'you.']
# ['Sally:']
# ['Tempy:']
# ['Page', '19/64']
# ['Sally:']
# ['and', 'see', 'if', 'Johnny', 'is', 'with', 'him.']
# ['Doshy:']
# ['Doshy:']
# ['Johnny:']
# ['Remus:']
# ['Sally:']
# ['Remus:']
# ['Tempy', 'tell', 'you', 'he', 'was', 'wid', 'me?']
# ['Sally:']
# ['but', "it's", 'so', 'long', 'past', "Johnny's", 'bedtime.']
# ['Remus:']
# ['I', 'was', "tellin'", 'him', 'a', 'tale', "'bout", 'Brer', 'Rabbit.']
# ['Remus:']
# ['Sally:']
# ['Sally:']
# ["it's", 'too', 'late', 'for', 'him', 'to', 'be', 'up.']
# ['Remus:']
# ['Sally:']
# ['run', 'along', 'upstairs', 'and', 'get', 'ready', 'for', 'bed.']
# ['Toby:']
# ['Tempy:']
# ['home', "befo'", "yo'", 'maw', 'takes', 'a', 'stick', 'after', 'you?']
# ['Doshy:']
# ['Remus:']
# ['What', 'us', 'gonna', 'do', "'bout", 'dat', 'child?']
# ['Page', '20/64']
# ['Doshy:']
# ["doesn't", 'count', 'for', 'much', 'these', 'days.']
# ['Remus:']
# ['What', 'dat', 'child', 'needs', 'is', 'his', 'paw.']
# ['Doshy:']
# ['But', "I'm", 'afraid', "it's", 'going', 'to', 'take']
# ['Doshy:']
# ['Remus:']
# ['Miss', 'Doshy,', 'if', 'you', "jes'", 'draps', 'a', 'word.']
# ['Doshy:']
# ["I'm", 'a', 'stubborn', 'old', 'woman', 'Uncle', 'Remus']
# ['Remus:']
# ['I', 'knows', 'dat.', 'Well,', 'goodnight.']
# ['Doshy:']
# ['Remus:']
# ['me,', 'is', 'you,', 'Miss', 'Doshy?']
# ['Doshy:']
# ['Of', 'course', "I'm", 'not', 'mad', 'with', 'you.']
# ['Children', 'laughing']
# ['Toby:']
# ['Johnny:']
# ['Johnny:']
# ['Say', "'knee-deep',", 'Brer', 'Frog,', "'knee-deep',", "'knee-deep'."]
# ['Toby:']
# ['Johnny:']
# ['Toby:']
# ['Johnny:']
# ['Frog', 'ribbits']
# ['Page', '21/64']
# ['Johnny:']
# ['breakfast', 'and', 'get', 'some', 'more.']
# ['Toby:']
# ["Remus'll", 'let', 'us', 'use', 'his', 'frog', 'box.']
# ['Johnny:']
# ['Sally:']
# ['Toby', 'and', 'Johnny:']
# ['Sally:']
# ['Johnny:']
# ['whispering', 'to', 'Toby', 'Come', 'on!', 'Take', 'him!']
# ['Johnny', 'giggles']
# ['Frog', 'ribbits']
# ['Sally:']
# ["Let's", 'hurry', 'up', 'and', 'get', 'dressed.']
# ['Johnny:']
# ['Sally:']
# ['mother', 'is', 'coming', 'to', 'see', 'us', 'today.']
# ['Johnny:']
# ['Sally:']
# ['Sally:']
# ['Johnny:']
# ['Sally:']
# ['You', 'can', 'go', 'another', 'day.']
# ['Sally:']
# ['and', 'come', 'on', 'down', 'to', 'breakfast.']
# ['Toby:']
# ['mill', "pon'", "won't", 'hurt', "yo'", 'clothes', 'none.']
# ['Page', '22/64']
# ['Johnny:']
# ['Toby:']
# ['gotter', 'take', 'Brer', 'Frog', 'back,', "ain't", 'we?']
# ['Toby:']
# ['to', 'get', 'stomped', 'on..', 'or', 'runned', 'over..', 'or', 'lost.']
# ['Toby:']
# ['Like', "yo'", 'miss', "yo'", 'fambly.']
# ['Toby:']
# ['saw', "yo'", 'maw', 'or', 'paw', "ag'in."]
# ['Johnny:']
# ['taking', 'him', 'back', "ain't", 'frog', "huntin'!"]
# ['Toby', "'Cose", "'tain't!", 'Come', 'on!']
# ['Toby:']
# ['we', 'kin', 'git', 'dar', 'a', 'heap', 'quicker.', 'Here!']
# ['Johnny:']
# ['Toby:']
# ['Johnny:']
# ['Toby:']
# ['Toby:']
# ['Johnny:']
# ['Toby:']
# ['Toby:']
# ['Johnny:']
# ['Toby:']
# ['bad.', "An'", 'if', "it's", "blowin'", 'towards', 'de', 'bull,', 'dat', "ain't", 'good.']
# ['Toby:']
# ['Page', '23/64']
# ["comin'", 'an', 'ketch', 'you', 'on', 'his', 'horns', 'sho!']
# ['Toby:']
# ['Johnny:']
# ['Joe:']
# ['Jake:']
# ['Joe:']
# ['Ginny:']
# ['Jake:']
# ['Toby:']
# ['Toby:']
# ['Joe:']
# ["befo'", 'I', 'knock', "yo'", 'head', 'clean', 'off.']
# ['Jake:']
# ['Joe:']
# ['Jake:']
# ['Look,', 'Joe.']
# ['Joe:']
# ['Jake:']
# ['Joe:']
# ['Jake', 'and', 'Joe:']
# ['Jake', 'and', 'Joe:']
# ["Wearin'", 'a', 'lace', 'collar!']
# ['Many', 'frogs', 'ribbit']
# ['Johnny:']
# ['Page', '24/64']
# ['Ginny:']
# ['Johnny:']
# ['Ginny:']
# ['They', 'was', 'gonna', 'drown', "'im."]
# ['Ginny:']
# ['Johnny:']
# ['Johnny:']
# ['Johnny:']
# ['Ginny:']
# ['Johnny:']
# ['Ginny:']
# ['Johnny:']
# ['Singing', 'Johnny:']
# ["It's", 'the', 'truth,', "it's", 'actual.', 'Everything', 'is', 'satisfactual.']
# ['Singing', 'Johnny:']
# ['zip-a-dee-ay,', 'wonderful', 'feeling,', 'wonderful', 'day.']
# ['Tempy:']
# ['where', 'he', 'come', 'from,', "jes'", 'like', "yo'", 'maw', "tol'", 'you.']
# ['Tempy:']
# ['Johnny:']
# ['If', 'I', 'take', 'you', 'back,', 'that', 'Jack', "Favers'll", 'drown', 'you.']
# ['Remus:']
# ['how', 'come', 'he', 'get', 'so', 'fat,']
# ['Remus:']
# ['along,', 'he', 'plays', 'like', 'dead,']
# ['Remus:']
# ['Page', '25/64']
# ['Remus:']
# ['I', "can't", 'see', "nothin'", 'wrong,', 'while', 'other', 'folks', 'is', "worryin'"]
# ['Remus:']
# ['Remus:']
# ["That's", 'what', 'I', 'abso-positive-i-lutely,', 'wants', 'to', 'do.']
# ['Remus:']
# ["Ain't", 'dat', 'one', "o'", 'dem', 'Favers', 'Dawgs?']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ['turn', "'roun'", 'and', 'tote', 'dat', 'dawg', 'right', 'back!']
# ['Johnny:']
# ['Remus:']
# ['when', 'you', 'come', 'home', 'wid', 'dat', 'dog?']
# ['Remus:']
# ['no', "'count", 'puppy', 'like', 'dat!']
# ['Johnny:']
# ['But', 'it', 'might', 'be', 'all', 'right', 'if...', 'you', 'kept', 'him.']
# ['Remus:']
# ["ol'", "Unc'", 'Remus', 'to', 'keep', 'dat', 'dawg!']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ['Remus:']
# ["an'", "lettin'", "im'", 'in.']
# ['Remus:']
# ["Co'se,", "don't", "'speck", 'a', "li'l", 'dawg', 'like', 'dat', "'ud"]
# ['Page', '26/64']
# ['Remus:']
# ["can't", 'git', 'uster', 'all', 'dat', "hollerin'", 'and', "squallin'."]
# ['Remus:']
# ["Co'se", 'I', 'got', 'a', "li'l", 'corner', 'what', "ain't", "bein'", 'used.']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ["An'", 'den', "ag'in", 'he', "mightn't.", 'Come', 'here', 'you', "li'l", 'Rascal.']
# ['Remus:']
# ['if', 'he', "don't", 'act', 'like', 'he', 'think', "I'm", 'gonna', 'take', "'im."]
# ['Remus:']
# ['Music', 'Chorus:']
# ['wake', 'up', 'early', 'in', 'the', 'morning,', 'when', 'the', 'ding', 'dong', 'ring,']
# ['Music', 'Chorus:']
# ["It's", 'the', 'same', "ol'", 'thing,', 'want', 'to', 'get', 'a', 'bite', 'of', "something',"]
# ['Music', 'Chorus:']
# ['look', 'up,', 'get', "yer'", 'finger', 'in', 'the', "dumplin'"]
# ['Music', 'Chorus:']
# ['Let', 'the', 'rain', 'pour', 'down.', 'Let', 'the', 'cold', "win'", 'blow,']
# ['Music', 'Chorus:']
# ['in', 'the', 'home', 'I', 'know.']
# ['Music', 'Chorus:']
# ["havin'", 'trouble', 'with', 'de', 'weevil,', 'never', 'did', 'like', 'that,']
# ['Music', 'Chorus:']
# ['like', 'a', "hypocrite's", 'hat,', 'when', 'the', 'weevil', 'git', 'the', 'cotton,']
# ['Music', 'Chorus:']
# ["there'll", 'be', "nothin'", 'on', 'de', 'table,']
# ['Music', 'Chorus:']
# ['Page', '27/64']
# ['let', 'the', 'rain', 'pour', 'down.']
# ['Remus:']
# ["Ain't", 'I', 'done', "tol'", 'you?', 'Go', 'on', 'away!']
# ['Remus:']
# ['Stop', "pesterin'", 'me', "'bout", 'dis', 'yere', 'dawg.']
# ['Remus:']
# ['Johnny', 'tells', 'me.', "He's", "yo'", 'dawg,', "ain't", 'he?']
# ['Johnny:']
# ['Jake:']
# ['Johnny:']
# ['Joe:']
# ['Jake:']
# ['Johnny:']
# ['Remus:']
# ['word', 'bout', 'dishyer', 'puppy,', "I'll..."]
# ['Remus:']
# ["I'll", 'do', 'it,', "sho's", "I'm", 'name', 'Remus!']
# ['Jake:']
# ['Joe:']
# ['Ginny:']
# ["Don't", 'you', 'pay', 'no', "'tenshun", 'to', 'them.']
# ['Ginny:']
# ["'Cause", 'maw', 'says', 'if', 'I', 'give', "'im", 'to', 'you,', "he's", 'yours.']
# ['Ginny:']
# ["she'll", 'whale', 'the', 'daylights', 'out', 'of', "'um."]
# ['Johnny', 'laughs']
# ['Remus:']
# ['Page', '28/64']
# ['got', "yo'", "se'f", 'in', 'a', 'peck', "o'", 'trouble.']
# ['Remus:']
# ['when', 'it', 'come', 'to', "stickin'", "yo'", 'foot', 'in', 'it.']
# ['Johnny:']
# ['Remus:']
# ["an'", 'stuck', 'his', 'foot', 'into', "sump'n", 'he', "don't", 'know', "nothin'", 'bout,']
# ['Remus:']
# ['fust', 'place.', "Ain't", 'you', 'never', 'heard', 'dat', 'tale?']
# ['Johnny:']
# ['Remus:']
# ['Remus:']
# ['Remus:']
# ['not', "yo'", 'time,', 'nor', 'yit', 'my', 'time...']
# ['Remus:']
# ['thinking', 'how', 'the', 'flowers', 'and', 'critters', 'was', 'curious', 'things...']
# ['Remus:']
# ['if', "it's", 'whistling', 'a', 'tune', 'or', 'singing', 'a', 'song,', 'they', 'all', 'say...']
# ['Remus:']
# ['Butterflies:']
# ['Remus:']
# ['Butterfly:']
# ['Remus:']
# ['Music', 'Chorus:']
# ['Music', 'Chorus:']
# ["meetin',", 'how', 'do', 'you', 'do,', 'with', 'everyone', "repeatin'..."]
# ['Music', 'Chorus:']
# ['Page', '29/64']
# ['Rabbit:']
# ['Rabbit:']
# ['howdy', 'you', 'and', 'you', 'howdy', 'back,', 'this', 'for', 'that', 'and', 'tit', 'for', 'tat.']
# ['Rabbit:']
# ['Remus:']
# ['Rabbit:']
# ['Remus:']
# ['Remus:']
# ['Rabbit:']
# ["an'", 'so', 'does', 'the', 'flea', '-', 'i', 'do', 'what', 'i', 'like,', "an'", 'i', '--']
# ['Rabbit:']
# ['Remus:']
# ['gonna', 'fetch', 'up', 'at,', 'i', "sho'ly", "don't."]
# ['Remus:']
# ['Possum:']
# ['Rabbit:']
# ['Possum:']
# ['Remus:']
# ['now', 'what', 'do', 'you', 'do', 'with', 'all', "yo'", 'time?']
# ['Rabbit:']
# ["dat's", 'what', 'you', 'axe', 'me', "an'", "dat's", 'what', 'you', 'knows.']
# ['Rabbit:']
# ['Frog:']
# ['Rabbit:']
# ['Page', '30/64']
# ['Fish:']
# ['Rabbit', 'whistles']
# ['Frog:']
# ["you's", "headin'", 'for', 'trouble', 'one', "o'", 'these', 'days.']
# ['Remus:']
# ['Rabbit:']
# ['Rabbit', 'whistles']
# ['Remus', 'laughs']
# ['Remus:']
# ['is', "sho'", 'a', 'caution...he', 'sho', 'is.']
# ['Frog:']
# ['that', '...', 'oh', 'thanks...']
# ['Frog:']
# ['put', 'his', 'foot', 'in', 'it', 'one', "o'", 'these', 'days.']
# ['Remus:']
# ['but', 'Brer', 'Rabbit', 'was', "a-headin'..."]
# ['Remus:']
# ['on', 'chickapin', 'hill', 'at', 'de', 'edge', 'of', 'de', 'big', 'woods...']
# ['Remus:']
# ["'bout", 'the', "where'bouts", "o'", 'Brer', 'Rabbit.']
# ['Fox:']
# ['come', 'right', 'now.', "Lem'me", 'see,', 'where', 'was', 'I?']
# ['Fox:']
# ['Gotta', 'get', 'a', 'head', 'right', 'quick.', 'Need', 'about', 'this', 'much', 'tar.']
# ['Fox:']
# ["'bout", 'right', 'for', 'a', 'head.', 'That', 'biggity', "ol'", 'rabbit']
# ['Fox:']
# ["We'll", 'catch', 'him', "sho'...", "i'll", 'catch', 'him', "sho'."]
# ['Bear:']
# ['last', 'time', "befo',", 'and', 'de', 'time', "befo'", 'dat', 'and', 'da...']
# ['Page', '31/64']
# ['Bear:']
# ['Fox:']
# ['Dey', "ain't", "nothin'", 'smart', "'bout", 'dat!']
# ['Fox:']
# ['smartest', 'is,', "an'", 'de', 'tar', 'baby', 'do', 'de', 'rest.']
# ['Fox:']
# ['Bear:']
# ["gon'", 'fool', 'nobody', '...', 'it', "hain't", 'got', 'no', 'eyes!']
# ['Fox:']
# ["I'm", 'glad', 'i', 'thought', 'of', 'that!']
# ['Fox:']
# ['let', 'me', 'see', 'about', 'this.', 'Just', "'bout", 'this', 'size.']
# ['Fox:']
# ['Oh,', 'yes.', 'A', 'nose', 'too...']
# ['Fox:']
# ['those', 'very', 'very', 'badly.', 'Got', 'to', 'have', 'a', 'nose.']
# ['Fox:']
# ['This', 'is', "lookin'", "mo'", 'natural', 'all', 'de', 'time.']
# ['Bear:']
# ['Fox:']
# ['Fox:']
# ["hep'", 'me', "'long,", "hep'", 'me', 'long,', 'come', 'on.']
# ['Fox:']
# ['coming', 'down', 'de', 'road.', 'Come', 'on.']
# ['Fox:']
# ['any', 'minute.', "Everythin'", "gotta'", 'be', 'just', 'right.']
# ['Fox:']
# ['lem-me', 'see', '--', 'Maybe', 'you', 'oughtta', 'have', 'a', 'hat.']
# ['Page', '32/64']
# ['Fox:']
# ['Now', 'maybe', 'if', 'he', 'had', 'one', '...']
# ['Bear:']
# ['Rabbit', 'whistling']
# ['Bear:']
# ['Fox:']
# ['Fox:']
# ['Hurry,', 'hurry.', 'Gotta', 'get', 'a', 'move', 'on.', 'Come', 'on!']
# ['Fox:']
# ['Fox:']
# ['Bear:']
# ['Remus:']
# ['fixed', 'up', "jes'", 'in', 'de', 'nick', "o'", 'time', 'cuz', 'right', 'then', 'Brer', 'Rabbit']
# ['Remus:']
# ['just', 'as', 'fast', 'as', 'a', 'jay', 'bird.', 'Till', 'by', 'and', 'by', 'he', 'spotted']
# ['Remus:']
# ['Rabbit:']
# ['Remus:']
# ['tar', 'baby', 'to', 'say', "'fine,", 'how', 'are', "you'..."]
# ['Remus:']
# ['say', "nothin',", "an'", 'brer', 'fox,', 'he', 'lay', 'low', '...', 'so', '...']
# ['Remus:']
# ['Rabbit:']
# ['Remus:']
# ['Remus:']
# ['ear', 'with', 'his', 'off', "behin'", 'foot', "an'", "'low", '...']
# ['Page', '33/64']
# ['Remus:']
# ['he', "cain't", 'get', 'no', 'answer.']
# ['Remus:']
# ['Rabbit:']
# ['howdy!', 'Is', 'you', 'hard', "o'", "hearin'?", 'Ah', 'said', 'howdy!']
# ['Remus:']
# ['Remus:']
# ['Fox:']
# ['I', "sho'", 'hope', '...', 'it', 'does', '...', 'ha', 'ha!']
# ['Remus:']
# ['de', 'stuck-up', 'stranger', 'some', 'manners,', "an'", 'he', 'say', '...']
# ['Rabbit:']
# ['I', 'counts', 'three,', "i's", "goin'", "bus'", 'you', 'wide', 'open!']
# ['Remus:']
# ['he', "don't", 'say', "nothin'", "an'..."]
# ['Remus:']
# ['Fox:']
# ['Remus:']
# ['Rabbit:']
# ['Remus:']
# ['Remus:']
# ["an'", 'chuckle', 'in', 'his', 'stomach.']
# ['Rabbit:']
# ['Remus:']
# ['Brer', 'Fox,', 'he', 'lay', 'low', 'wid', 'de', 'fidgets.']
# ['Rabbit:']
# ['Page', '34/64']
# ['Rabbit:']
# ['Rabbit:']
# ['Rabbit:']
# ['Fox:']
# ['Laughs']
# ['Rabbit:']
# ["I'll", 'poke', 'you', "ag'in", '...', 'lem-me', 'go!']
# ['Remus:']
# ['and', 'he', 'hauled,', 'he', 'kicked', 'and', 'he', 'screamed,', 'and', 'he', 'blubber']
# ['Remus:']
# ['thrash', "aroun',", 'the', 'wus', 'off', 'he', 'gits,', 'til', 'he', 'so', 'stuck', 'up,']
# ['Remus:']
# ['Fox', 'whistling']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['Fox:']
# ['all', 'stuck', 'up', 'in', "yo'", 'swaller', 'tail', 'coat!']
# ['Fox:']
# ['I', "ain't", 'never', 'seen', 'nobody', 'look', 'dat', 'good', "befo'."]
# ['Bear:']
# ['Fox:']
# ['Bear:']
# ['Page', '35/64']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['He', 'forgot', 'everything,', "didn't", 'he', 'Brer', 'Bear?']
# ['Remus:']
# ['dat', 'had', 'humble', 'come-tumbleness', 'down', 'as', 'fine']
# ['Remus:']
# ['poor', "li'l", 'critter', '--', 'He', 'learned', 'a', "pow'ful", 'lesson,']
# ['Remus:']
# ['show', 'you', 'what', 'comes', "o'", "mixin'", 'up', 'wid', "somethin'"]
# ['Remus:']
# ["an'", "don't", 'you', 'never', 'forget', 'it!']
# ['Johnny:']
# ['get', 'away,', 'Uncle', 'Remus?']
# ['Remus:']
# ['Toby:']
# ['Remus:']
# ["ain't", 'i', 'done', "tol'", 'you', 'that', 'Brer', 'Rabbit,', "bein'"]
# ['Remus:']
# ['to', 'use', 'his', 'head', "'stead", "o'", 'his', 'foots?']
# ['Johnny:']
# ['Toby:']
# ['Remus:']
# ['Toby:']
# ['Page', '36/64']
# ['Remus:']
# ['Well,', 'suh,', 'dar', 'he', 'was,', "sittin'", 'in', 'de', 'middle', "o'", 'de', 'road', '--']
# ['Remus:']
# ['Only', "he's", 'all', 'mixt', 'up', 'wid', 'dat', 'tar', 'baby', '...']
# ['Remus:']
# ['finish', "fo'", "po'", "li'l", 'Brer', 'Rabbit,', 'cuz', "ol'", 'Brer', 'Fox', '...']
# ['Remus:']
# ['him', "fo'", 'dinna,', 'right', 'den', "an'", 'dar.']
# ['Fox:']
# ["won't", 'be', 'long', 'now', '...', 'dinner', "goin'", 'be', 'ready', 'any']
# ['Fox:']
# ['a', 'few', 'more', 'sticks', 'on', 'the', 'fire.', 'Yes', '...']
# ['Fox:']
# ['is', 'gwine', 'stay', "fo'", 'dinner,', "ain'cha',", 'Brer', 'Rabbit?']
# ['Fox:']
# ['Now,', 'we', "jes'", 'love', 'to', 'have', 'you', "fo'", 'dinner!']
# ['Fox:']
# ['Brer', 'Bear?', "Ain't", 'dat', "jes'", 'what', 'you', 'been', "sayin'?"]
# ['Bear:']
# ['Bear:']
# ['Bear:']
# ['Fox:']
# ['Not', 'that,', 'no,', 'no,', 'not', 'that.']
# ['Fox:']
# ['No', 'wait!', 'Let', 'loose.', 'You', "can't", 'do', 'that.']
# ['Bear:']
# ["I'm", 'gonna...', 'now', "jes'", 'look....']
# ['Fox:']
# ['Page', '37/64']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ["We're", 'gonna', 'make', 'him', 'suffer.']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['my', 'little', 'head', 'I', 'knowed', 'what', 'we', 'gonna', 'do....']
# ['Bear:']
# ["I'm", 'gonna', 'knock', 'his', 'head', 'clean', 'off']
# ['Rabbit:']
# ['go', 'on,', 'knock', 'my', 'head', 'clean', 'off.']
# ['Bear:']
# ['Rabbit:']
# ['Fox:']
# ["'Tain't", 'none', "o'", "yo'", 'business.']
# ['Fox:']
# ['Hang', 'him', 'by', 'the', 'neck', 'til', "he's", 'dead.']
# ['Rabbit:']
# ['Go', 'ahead,', 'but', "don't", 'flong', 'me', 'dat', 'briar', 'patch.']
# ['Fox:']
# ['so', "i'spects.", 'I', "'spects", "I'll", 'have', 'to', 'skin', 'ya.']
# ['Rabbit:']
# ['Fox:']
# ['Rabbit:']
# ['go', 'ahead.', 'Heh', 'heh,', 'yes', 'sir...skin', 'me', 'if', 'ya', 'likes,', 'Brer', 'Fox,']
# ['Rabbit:']
# ['Page', '38/64']
# ['one', 'thing', 'I', "don't", 'wantcha', 'to', 'do.']
# ['Fox:']
# ['Rabbit:']
# ['Rabbit:']
# ['I', 'mean...wa-wa-wa-', 'whatever', 'you', 'do,', 'Brer', 'Fox...']
# ['Rabbit:']
# ['Brer', 'Fox,', 'please', "don't", 'fling', 'me', 'in', 'dat', 'briar', 'patch.']
# ['Fox:']
# ['Fox:']
# ['Fox:']
# ['I', "sho'", 'am', 'glad', 'i', 'thought', 'of', 'that!']
# ['Rabbit:']
# ['fling', 'me', 'in', 'dar,', 'is', 'ya?']
# ['Fox:']
# ['Fox:']
# ['No', 'sir!', 'We', "wouldn't", 'do', 'dat!']
# ['Fox:']
# ['Brer', 'Bear?']
# ['Bear:']
# ['We', "jes'", 'gonna', 'knock', 'his', 'head', 'clean', 'off.']
# ['Fox:']
# ['minute!', 'Oh', 'no,', 'please', "don't!", 'Look', 'out,', 'stop!', 'There!']
# ['Rabbit:']
# ['Rabbit', 'makes', 'dying', 'sounds']
# ['Rabbit:']
# ['and', 'bred', 'in', 'de', 'briar', 'patch.', 'Laughs']
# ['Rabbit:']
# ['Born', 'and', 'bred', 'in', 'the', 'briar', 'patch.']
# ['Page', '39/64']
# ['Remus:']
# ['come-tumble,', 'but', "ol'", 'Brer', 'Bear,', 'he', "don't", 'say', "nuthin'."]
# ['Remus:']
# ['heh', 'heh...', 'mighty', 'low...', 'Sho', 'nuf.']
# ['Toby:']
# ['Johnny:']
# ['about', 'Brer', 'Frog', "havin'", 'a', 'tail...']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ['Remus', 'and', 'Johnny:', '...when', 'dey', "ain't", 'no', 'ta....']
# ['Remus:']
# ['but', "dat's", 'annudder', 'tale', 'for', 'annudder', 'day.']
# ['Remus:']
# ['pup', "somp'n", 'to', 'chew', 'on', 'sides', 'my', 'shoes.']
# ['Johnny:']
# ['Johnny:']
# ['Toby:']
# ['Johnny:']
# ['Toby:']
# ['Jake:']
# ["don't", 'mean', 'we', "ain't", 'gonna', 'git', 'Teenchy.']
# ['Jake:']
# ['Joe:']
# ['Jake:']
# ['Page', '40/64']
# ['Jake:']
# ['or', 'maybe', 'even', 'your', 'maw.']
# ['Johnny:']
# ['You', 'can', 'tell', 'aunt', 'Tempy....']
# ['Johnny:']
# ['you', 'can', 'even', 'tell', 'my', 'mama.']
# ['Johnny:']
# ["don't", 'tell', 'your', 'maw.']
# ['Jake:']
# ['Johnny:']
# ["that's", 'all!', 'If', 'you', 'do,', "it'll", 'be', 'awful!']
# ['Toby:']
# ['Johnny:']
# ['we', "s'posed", 'to', 'use', 'our', 'heads', 'instead', 'of', 'our', 'foots.']
# ['Maw', 'Favers:']
# ['wanta', 'hear', 'no', 'more', "'bout", 'it.']
# ['Maw', 'Favers:']
# ['wants', 'to', 'give', 'it', 'away,', "'tain't", 'none', "o'", "yo'", 'business.']
# ['Jake:']
# ["He'll", 'find', 'out!', "Think's", 'he', 'so', 'smart.']
# ['Joe:']
# ['He', 'told', 'us', 'not', 'to', 'tell', 'our', 'maw.']
# ['Jake:']
# ["jis'", 'what', 'he', 'wanted', 'us', 'to', 'do.']
# ['Tempy:']
# ['I', 'betcha,', 'I', 'betcha', 'that', 'I', 'getcha,', 'you', 'wait', 'and', 'see...']
# ['Tempy:']
# ['be', "hangin'", "aroun'...", 'I', 'betcha...']
# ['Tempy:']
# ['Page', '41/64']
# ['Your', 'gonna', 'knock', 'at', 'my', 'door...you', 'done', 'it', "befo'..."]
# ['Tempy:']
# ['but', 'sooner', 'or', 'later', "you're", 'gonna', 'be', 'hanging', "aroun',"]
# ['Tempy:']
# ['Your', 'gonna', 'knock', 'on', 'my', 'door,', 'you', "don'", 'it', "befo'"]
# ['Tempy:']
# ['cuz', 'sooner', 'or', 'later', 'I', 'know', "you'll", 'be', 'hangingn', "aroun',"]
# ['Tempy:']
# ['But', 'you', "ain't", 'gonna', 'get', 'it.']
# ['Tempy:']
# ['and', "totin'", 'in', 'three', 'or', 'four', 'measley']
# ['Tempy:']
# ['Some', 'folks', 'does', 'de', 'work,', 'while', 'others', 'jest', 'visits.']
# ['Tempy:']
# ['like', 'Brer', 'Fox', 'and', 'Brer', 'Rabbit.']
# ['Tempy:']
# ['kitchen', 'and', 'we', 'have', 'Brer', 'Rabbit', 'stew.']
# ['Remus:']
# ['and', 'I', 'says', 'it', "again'", 'there', 'never', 'was', 'a', 'better', 'cook']
# ['Remus:']
# ['Tempy:']
# ['wool', 'over', 'my', 'eyes.', 'Here!']
# ['Chloe:']
# ['Jake:']
# ['Joe:']
# ['Chloe:']
# ['Jake:']
# ['Page', '42/64']
# ['Joe:']
# ['Remus:']
# ["It's", "Johnny's."]
# ['Tempy:']
# ['Remus:']
# ['Tempy:']
# ['to', 'take', 'it', 'right', 'straight', 'back', 'what', 'he', 'got', 'it.']
# ['Remus:']
# ['Remus:']
# ['Chloe:']
# ['Remus:']
# ['Remus:']
# ['folks', "'bout", 'dat', 'mangy', "ol'", 'puppy?']
# ['Remus:']
# ["befo'", 'i', 'gits', 'fractious!']
# ['Jake:']
# ['Joe:']
# ['Remus:']
# ['time', 'to', 'be', 'bothered', 'wid', 'you.']
# ['Remus:']
# ['talk', 'about', 'dat', 'dawg,', 'neither.']
# ['Sally:']
# ['Jake:']
# ['--', "An'", 'we', 'we', 'wants', 'it', 'back!']
# ['Sally:']
# ['mean', 'that', 'little', 'puppy?']
# ['Page', '43/64']
# ['Jake:']
# ["ol'", "Remus's", "so's", 'you', "wouldn't", 'know.']
# ['Sally:']
# ['Remus:']
# ['miss', 'sally,', 'I', 'had..']
# ['Sally:']
# ['dog', 'back', 'to', 'you.', 'Now', 'run', 'along,', 'please.']
# ['Joe:']
# ['Jake:']
# ['Jake:']
# ['care', 'if', 'we', 'told', 'you....']
# ['Jake:']
# ['Joe:']
# ['she', "giv'd", 'us', 'a', "whuppin'."]
# ['Remus:']
# ['Sally,', 'Johnny', "didn't", 'mean', 'no', 'harm.']
# ['Remus:']
# ['Brer', 'Rabbit.', 'I', "tol'", 'him', 'a', 'tale', "'bout", 'de']
# ['Remus:']
# ['bodacious,', 'and', 'outreached', "hisse'f,", "dat's", 'all.']
# ['Sally:']
# ['Johnny', 'to', 'be', 'obedient', 'and', 'truthful.', 'But', 'you', 'and', 'your']
# ['Sally:']
# ['it', 'would', 'be', 'better', 'if', 'he', "didn't", 'hear', 'any', 'more', 'for', 'awhile.']
# ['Remus:']
# ['de', 'stories', "ain't", 'done', 'no....']
# ['Sally:']
# ['mean', 'well,', 'Uncle', 'Remus,', 'but', "Johnny's", 'too', 'young.']
# ['Page', '44/64']
# ['Remus:']
# ['Sally:']
# ['not', 'to', 'tell', 'him', 'any', 'more.']
# ['Remus:']
# ['Sally:']
# ["can't", 'just', 'overlook', 'it,', 'he', 'has', 'to', 'learn', 'to', 'mind.']
# ['Doshy:']
# ['Uncle', 'Remus', 'and', 'his', 'stories,']
# ['Doshy:']
# ['He', 'needs', 'something', 'to', 'hold', 'on', 'to.']
# ['Sally:']
# ['mother....and', 'his', 'grandmother.']
# ['Doshy:']
# ['friends.', 'And', 'if', "it's", 'not', 'Uncle', 'Remus,', 'or', 'the', 'Favers']
# ['Doshy:']
# ['someone', 'of', 'his', 'own', 'age.', "That's", 'just', 'good', 'common', 'sense.']
# ['Tempy:']
# ["Ain't", 'I', 'done', "tol'", 'you', "'bout", "messin'", "'roun'", 'my', 'kitchen?']
# ['Sally:']
# ['Johnny:']
# ['Sally:']
# ['Johnny:']
# ['Sally:']
# ['And', 'what', 'happens', 'then?']
# ['Johnny:']
# ['Sally:']
# ['party.', 'Would', 'you', 'like', 'that?']
# ['Page', '45/64']
# ['Johnny:']
# ['Sally:']
# ['little', 'boys', 'and', 'girls.']
# ['Johnny:']
# ['Sally:']
# ['many', 'other', 'children,', 'dear...']
# ['Doshy:']
# ["won't", 'make', 'any', 'difference.']
# ['Johnny:']
# ['Sally:']
# ['write', 'and', 'ask', 'him.']
# ['Johnny:']
# ['Johnny:']
# ['Johnny:']
# ['Teenchy!', 'Where', 'are', 'you?']
# ['Johnny:']
# ['for', 'Teenchy!', "Where's", 'Teenchy?']
# ['Remus:']
# ['Johnny:']
# ['might', 'happen', 'to', 'him...', 'if', 'he', 'runs', 'around', 'loose.']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ['what', 'he', "b'longs", "an'", 'you', 'knows', 'it.']
# ['Johnny:']
# ['my', 'dog.', "He's", 'mine.']
# ['Johnny:']
# ['Page', '46/64']
# ['to', 'me,', 'and', 'you', 'said...']
# ['Remus:']
# ["tol'", 'you', 'to', 'take', 'dat', 'dawg', 'back', 'whar', 'he']
# ['Remus:']
# ['She', "don't", 'like', 'dat,', "an'", 'I', "don't", 'blame', 'her.']
# ['Johnny:']
# ["botherin'", 'anybody.']
# ['Remus:']
# ['know', "what's", "bes'", 'for', 'you!']
# ['Johnny:']
# ['loves', 'me.', 'You', "should'na", 'done', 'it,', 'Uncle', 'Remus.']
# ['Johnny:']
# ['him!', 'I', 'know', 'he', 'will.']
# ['Remus:']
# ['on.', "Puppy's", 'gone', "an'", "dat's", 'dat.']
# ['Johnny:']
# ['gone...and', 'you', "don't", 'care', 'at', 'all.']
# ['Remus:']
# ['whether', 'I', 'does', 'or', 'whether', 'I']
# ['Remus:']
# ['man', 'what', "ain't", 'no', 'good', 'to', 'nobody.']
# ['Johnny:']
# ["you're...the", 'best', 'friend', 'i', 'have.']
# ['Remus:']
# ["don't", 'know', 'whether', "i'm", 'end-upperds', 'or']
# ['Remus:']
# ['I', "ain't", "goin'", 'ter', 'be', "tellin'", 'you', 'no', "mo'", 'stories.']
# ['Children:']
# ['craney', 'crow!', 'I', 'went', 'to', 'the', 'well', 'to', 'wash']
# ['Page', '47/64']
# ['Childern:']
# ['was', 'bare!', 'What', 'time', 'is', 'it,', 'old', 'witch!']
# ['Ginny:']
# ['Maw', 'Favers:']
# ['Ginny:']
# ['The', "party'll", 'be', 'over.']
# ['Maw', 'Favers:']
# ['and', 'down', "I'll", 'never', 'get', 'this', 'collar', 'on.']
# ['Ginny:']
# ['Maw', 'Favers:']
# ['what', 'you', 'says', 'when', 'you', 'does', 'it.']
# ['Ginny:']
# ['Maw', 'Favers:']
# ['looks', 'pretty', 'enough', 'to', 'go', 'anywheres.']
# ['Johnny:']
# ['Maw', 'Favers:']
# ['forgit', 'your', 'manners.']
# ['Ginny:']
# ['Joe:']
# ['Johnny:']
# ['you', 'were', 'never', "comin'."]
# ['Ginny:']
# ['maw', 'had', 'an', 'awful', 'time', 'finishing', 'my', 'dress.', 'Like', 'it?']
# ['Johnny:']
# ['Ginny:']
# ["weddin'", 'dress.', 'Are', 'we', 'gonna', 'have', 'cake?']
# ['Johnny:']
# ['Page', '48/64']
# ['right', 'now.', 'But', "there'll", 'be', 'plenty', 'left.']
# ['Ginny:']
# ['party', '--', "'Sides", 'have', 'cake?']
# ['Johnny:']
# ['Play', 'games,', "an'...get", 'presents.']
# ['Ginny:']
# ['Johnny:']
# ['does.', 'Course,', 'I', 'get', 'the', 'most.']
# ['Jake:']
# ['Ginny:']
# ['Jake:']
# ['Ginny:']
# ['Jake:']
# ['Johnny:']
# ['attention', 'to', 'them,', 'Ginny.']
# ['Joe:']
# ["'tenshun", 'to', "'em,", 'Ginny!']
# ['Ginny:']
# ['Joe:']
# ['Ginny:']
# ['Ginny', 'Crying']
# ['Ginny:']
# ['Ginny', 'Crying']
# ['Ginny:']
# ['Jake:']
# ['Jake:']
# ['Page', '49/64']
# ['Jake:']
# ['Johnny:']
# ['Jake:']
# ['Johnny:']
# ['Jake:']
# ['Jake:']
# ['Remus:']
# ['Remus:']
# ['Get', 'off', "'im!", 'Now', 'you', 'git', "'long", '--', "An'"]
# ['Remus:']
# ["'roun'", 'dese', 'chillun', 'no', "mo'!", "An'", 'ah', 'means', 'it.']
# ['Johnny:']
# ['Johnny:']
# ['Johnny:']
# ['Johnny:']
# ['the', 'party...', 'if', 'you', 'wanta.']
# ['Johnny:']
# ['Ginny:']
# ['Johnny:']
# ['of', 'an', "ol'", 'party', 'anyway.']
# ['Johnny:']
# ['rabbit!', 'Now', 'let', 'me', 'see', '--', "'Bout", 'this', 'here', 'brer', 'rabbit...']
# ['Johnny:']
# ['critter', 'in', 'the', 'whole', 'world.', 'Anyway...']
# ['Johnny:']
# ['Page', '50/64']
# ['all', "havin'", 'a', 'big', 'party...']
# ['Ginny', 'begins', 'to', 'cry', 'again']
# ['Johnny:']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ['Remus:']
# ["Ol'", 'Uncle', "Remus'll", 'take', 'care', 'of', 'you.']
# ['Remus:']
# ['find', 'Sis', 'Tempy', 'to', 'clean', 'you', 'up']
# ['Remus:']
# ['Johnny:']
# ['Remus:']
# ['Remus:']
# ["o'", 'trouble', 'wid', 'dis', 'party.']
# ['Johnny:']
# ['and', "Ginny's", 'all', 'ldirty.', 'Please,', 'Uncle', 'Remus.']
# ['Remus:']
# ["I'se", 'got', 'troubles', 'too.']
# ['Remus', 'laughing']
# ['Remus:']
# ['But', 'dey', "ain't", 'none', 'of', 'us', 'ever', 'had']
# ['Remus:']
# ['I', "'members", 'one', 'time', 'he', 'had', "mo'", 'troubles']
# ['Remus:']
# ['rolled', 'into', 'one.']
# ['Remus:']
# ['way', 'down', 'in', 'Brer', "Fox's", 'cave.']
# ['Page', '51/64']
# ['Remus:']
# ['run', 'out,', "fo'", 'sho.']
# ['Remus:']
# ['used', 'up', 'his', 'whole', 'bag', "o'", 'tricks.']
# ['Fox:']
# ['trick', 'on', 'me,', 'Brer', 'Rabbit.']
# ['Fox:']
# ['played', 'your', 'last', 'trick', 'on', 'me.']
# ['Fox:']
# ['mighty', 'good', 'in', 'that', 'bow-tie,', 'Brer', 'Rabbit.']
# ['Fox:']
# ['good', 'in', 'that', 'bow-tie.']
# ['Fox:']
# ['bow-tie', 'Brer', 'Bear?']
# ['Fox:']
# ['dressed', 'with', 'a', 'bow-tie', "befo'."]
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['up', 'for', 'dinner.', 'Fo', 'my', 'dinner.']
# ['Fox:']
# ['you', 'dis', 'very', 'minute,', 'on', 'dat', 'fire.']
# ['Rabbit', 'laughing']
# ['Rabbit:']
# ['Fox:']
# ['Wait', "jes'", 'a', 'minute,', 'Brer', 'Rabbit.']
# ['Fox:']
# ["'splain", 'something', 'to', 'you.']
# ['Page', '52/64']
# ['Fox:']
# ['you...', 'on', 'dat', 'fire!', 'Now!']
# ['Fox:']
# ['laugh', 'about?']
# ['Rabbit:']
# ["I'se", 'just', 'been', 'to', 'my', 'lauging', 'place.']
# ['Rabbit:']
# ['about', 'my', 'laughing', 'place,', 'I', "can't", 'help.']
# ['Bear:']
# ['Rabbit:']
# ['Bear:']
# ['laughing', 'place?']
# ['Rabbit:']
# ['place', 'I', 'knows', 'about.']
# ['Fox:']
# ["It's", 'another', 'one', "o'", 'his', 'tricks.']
# ['Fox:']
# ['Bear:']
# ['this', 'laughing', 'place', 'at?']
# ['Rabbit:']
# ['where', 'it', 'is', 'when', "I'se", 'all']
# ['Rabbit:']
# ['Bear:']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ["I'm", 'gonna', 'roast', 'him.']
# ['Page', '53/64']
# ['Fox:']
# ['fire.', "I'm", 'gonna...']
# ['Bear:']
# ['Rabbit', 'singing']
# ['Rabbit:']
# ['Rabbit:']
# ['place', 'and', 'yuk,', 'yuk,', 'yuk,', 'yuk,', 'yuk.']
# ['Fox:']
# ['Rabbit:']
# ['And', "you'll", 'find', 'yours,', 'I', 'know,', 'ho', 'ho.']
# ['Rabbit:']
# ['Bear:']
# ['Bear:']
# ['Rabbit:']
# ['Bear:']
# ['Rabbit:']
# ['And', "you'll", 'find', 'yours,', 'I', 'know,', 'ho', 'ho.']
# ['Fox:']
# ['this', 'has', 'gone', 'far', 'enough,', 'I...']
# ['Fox:']
# ['this', 'has', 'gone', 'far', 'enough.']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['Bear:']
# ['Fox:']
# ['Page', '54/64']
# ['Fox:']
# ['fool', 'out', 'of', 'you,', 'you', 'fool.']
# ['Bear:']
# ['Fox:']
# ['Fox:']
# ['as', 'a', 'laughing', 'place.']
# ['Bear:']
# ['Fox:']
# ['Fox:']
# ['go', 'and', 'have', 'some...']
# ['Rabbit:']
# ['Wait', 'a', 'minute.', 'There', 'it', 'is.']
# ['Bear:']
# ['Rabbit:']
# ['Bear:']
# ['Rabbit:']
# ['Fox:']
# ['Bear:']
# ['Bear', 'yells']
# ['Bear:']
# ['here', "'cept", 'bees.']
# ['Fox:']
# ['out', 'of', "yo'se'f", 'this', 'time.']
# ['Fox:']
# ['a', 'fool', 'outa', "yo'sef."]
# ['Fox:']
# ['Page', '55/64']
# ['look', 'dat', 'silly', "befo'."]
# ['Fox:']
# ['Bear:']
# ['was', 'a', "laughin'", 'place...']
# ['Bear:']
# ['Rabbit:']
# ['was', 'you', "laughin'", 'place.']
# ['Rabbit:']
# ['place', 'Brer', 'Bear.']
# ['Rabbit', 'Laughs']
# ['Johnny:']
# ['Ginny:']
# ['Remus:']
# ["ain't?", "Co'se", 'you', 'got', 'a', "laughin'", 'place.']
# ['Johnny:']
# ['Ginny:']
# ['Remus:']
# ['trouble', 'is,', "mos'", 'folks', "won't"]
# ['Remus:']
# ['Johnny', '&', 'Ginny:']
# ['Remus:']
# ['say.', "'Cause", 'where', "'tis", 'for', 'one,']
# ['Remus:']
# ["'tis", 'for', 'another.']
# ['Johnny:']
# ["Let's", 'start', 'lookin.']
# ['Sally:']
# ['Page', '56/64']
# ['Where', 'have', 'you', 'been?']
# ['Johnny:']
# ['Sally:']
# ['Sally:']
# ['been', 'doing?', 'The', "party's", 'all', 'over,', 'dear.']
# ['Sally:']
# ['to', 'tell', 'your', 'guests', 'goodbye.']
# ['Johnny:']
# ['Ginny:']
# ['Ginny:']
# ['a', "laughin'", 'place', "ma'am?"]
# ['Ginny:']
# ['got', 'one.', 'Pleased', 'to', 'meetcha.']
# ['Remus:']
# ['Sally:']
# ['Sally:']
# ["couldn't", 'stop', 'telling', 'your', 'stories.']
# ['Sally:']
# ['Remus,', 'but', 'from', 'now', 'on']
# ['Sally:']
# ['from', 'Johnny,', 'you', 'understand?']
# ['Sally:']
# ['Remus:']
# ['Music', 'Chorus:']
# ['let', 'the', 'cold', "win'", 'blow']
# ['Music', 'Chrous:']
# ['In', 'the', 'home', 'I', 'know.']
# ['Page', '57/64']
# ['Music', 'Chorus:']
# ['the', 'misery,', 'when', 'your', 'old', 'and', 'grey,']
# ['Music', 'Chorus:']
# ["playin'", "'round", 'yo', 'door.']
# ['Remus:']
# ["I'm", "jes'", 'a', "wo'", 'out', "ol'", 'man', 'what']
# ['Remus:']
# ['stories.', 'But', 'dey', "ain't", 'never', 'done']
# ['Remus:']
# ['if', 'dey', "don't", 'do', 'no', 'good,']
# ['Remus:']
# ['Remus:']
# ['Was', "goin'", 'ter', 'whitewash', 'de', 'walls,', 'too,']
# ['Remus:']
# ['Time', 'done', 'run', 'out.']
# ['Toby:']
# ["Unc'", 'Remus,', 'what', 'you', "doin'?"]
# ['Remus:']
# ['Ginny:']
# ['laughing', 'place?']
# ['Johnny:']
# ['Remus', 'say', 'so?']
# ['Ginny:']
# ['Johnny:']
# ['Ginny:']
# ['tell', "'im", "'bout", 'Brer', 'Rabbit!']
# ['Ginny:']
# ['Page', '58/64']
# ['Johnny:']
# ['Uncle', 'Remus,', "I've", 'found', 'it!']
# ['Johnny:']
# ["It's", 'right', 'here...']
# ['Johnny:']
# ['Uncle', 'Remus', 'is', 'gone.']
# ['Johnny:']
# ['Sally:']
# ['Johnny:']
# ['Sally:']
# ['Toby:']
# ['away!', "He's", "gettin'", 'in', 'de', 'wagon!']
# ['Johnny:']
# ['Uncle', 'Remus!']
# ['Sally:']
# ['Johnny:']
# ['Johnny:']
# ['Wait!']
# ['Sally', 'screams']
# ['Sally:']
# ['Music', 'Chorus:']
# ['faith', 'in', 'him.']
# ['Music', 'Solo:']
# ['and', 'the', 'moon', 'and', 'the', 'sun.']
# ['Music', 'Chorus:']
# ['faith', 'in', 'him.']
# ['Music', 'Solo:']
# ['and', 'the', 'birds', 'everyone.']
# ['Page', '59/64']
# ['Music', 'Chorus:']
# ['faith', 'in', 'him.']
# ['Music', 'Solo:']
# ['Music', 'Chorus:']
# ['All', 'I', 'want...', 'All', 'I', 'want...']
# ['Music', 'Chorus:']
# ['faith', 'in', 'him.']
# ['Music', 'Solo:']
# ['Music', 'Chorus:']
# ['John:']
# ['Toby:']
# ['He', 'got', 'hurt', 'by', 'dat', 'bull.']
# ['Tempy:']
# ['John:']
# ['Tempy:']
# ['suh,', "and'", "talkin'", 'like', 'his', "li'l", "heart's"]
# ['Tempy:']
# ['Mister', 'John,', 'he', 'was', "cuttin'"]
# ['Tempy:']
# ['to', 'stop', 'Uncle', 'Remus', 'from', "goin'", 'away.']
# ['Music', 'Chorus:']
# ['faith', 'in', 'him.']
# ['Music', 'Solo:']
# ['on', 'this', 'little', "chil'"]
# ['Music', 'Chorus:']
# ['faith', 'in', 'him.']
# ['Music', 'Solo:']
# ['Page', '60/64']
# ['such', 'a', 'mighty', "li'l", 'while.']
# ['Music', 'Chorus:']
# ['faith', 'in', 'him.']
# ['Sally:']
# ['Johnny:']
# ['Uncle', 'Remus!', 'Come', 'back!']
# ['John:']
# ['Johnny!']
# ['Johnny:']
# ['Doshy:']
# ['Remus:']
# ['de', 'chimney,', 'an', 'de', 'light', 'from']
# ['Remus:']
# ['Inside', 'de', 'house,', 'de', 'kittle', 'was', "singin'"]
# ['Remus:']
# ['de', 'cricket', 'was', 'a', "jiggin'", 'to', 'de', 'tune.']
# ['Remus:']
# ['satisfactual.', "'Cause", 'Brer', 'Rabbit']
# ['Remus:']
# ['laughing', 'place', 'wid', 'de', 'folks']
# ['Remus:']
# ['what', "b'longs", 'dar.']
# ['Johnny:']
# ['Remus:']
# ['de', 'happiest', 'Brer', 'Rabbit.']
# ['Remus:']
# ['place', 'in', 'de', 'whole', 'wide', "worl'."]
# ['Johnny:']
# ['Page', '61/64']
# ['Mama!', "Daddy's", 'here!', 'Mama!']
# ['John:']
# ['Sally:']
# ['Johnny:']
# ['Make', 'him', 'stay,', 'please!']
# ['John:']
# ["I'm", 'not', 'going', 'anywhere.']
# ['John:']
# ['where', 'I', 'belong.']
# ['Johnny:']
# ['John:']
# ['John:']
# ['than', 'Brer', 'Rabbit', "hisse'f."]
# ['Sally:']
# ['place', 'in', 'the', 'whole', 'wide', 'world.']
# ['John:']
# ['Remus:']
# ['mighty', 'satisfactual.', 'Mighty', 'satisfactual.']
# ['Johnny,', 'Ginny', '&', 'Toby', 'singing']
# ['Zip-a-dee-do-dah,', 'zip-a-dee-ay,']
# ['Johnny,', 'Ginny', '&', 'Toby', 'singing']
# ['My', 'oh', 'my,', 'what', 'a', 'wonderful', 'day.']
# ['Johnny,', 'Ginny', '&', 'Toby', 'singing']
# ['Plenty', 'of', 'sunshine,', "headin'", 'my', 'way.']
# ['Johnny,', 'Ginny', '&', 'Toby', 'singing']
# ['Zip-a-dee-do-dah,', 'zip-a-dee-ay.']
# ['Johnny:']
# ['shoulder.', "It's", 'the', 'truth,', "It's", 'actual.']
# ['Jonnny:']
# ['Johnny,', 'Ginny', '&', 'Toby', 'singing']
# ['Zip-a-dee-do-dah,', 'zip-a-dee-ay,']
# ['Page', '62/64']
# ['Johnny,', 'Ginny', '&', 'Toby', 'singing']
# ['Wonderful', 'feeling,', 'wonderful', 'day.']
# ['Johnny,', 'Ginny', '&', 'Toby', 'singing']
# ['Zip-a-dee-do-dah,', 'zip-a-dee-ay,']
# ['Johnny,', 'Ginny', '&', 'Toby', 'singing']
# ['My', 'oh', 'my,', 'what', 'a', 'wonderful', 'day.']
# ['Johnny,', 'Ginny', '&', 'Toby', 'singing']
# ['Plenty', 'of', 'sunshine', "headin'", 'my', 'way...']
# ['Rabbit:']
# ['Three', 'children:']
# ['Rabbit.', 'Hi', 'there,', 'Brer', 'Rabbit.']
# ['Rabbit:']
# ['them', 'zip-a-dee-do-dah', 'days.']
# ['Rabbit:']
# ['zip-a-dee-do-dah,', 'zip-a-dee-ay.']
# ['Children:']
# ['day,', 'plenty', 'of', 'sunshine', "headin'", 'my', 'way.']
# ['Children:']
# ['zip-a-dee-ay.']
# ['Johnny:']
# ['shoulder.']
# ['Remus:']
# ['Everything', 'is', 'satisfactual.']
# ['Children:']
# ['zip-a-dee-ay.']
# ['Children:']
# ['wonderful', 'day.']
# ['Children:']
# ['my', 'way,', 'wonderful', 'feeling,', 'wondeful', 'day.']
# ['Frog:']
# ['zip-a-dee-ay.']
# ['Page', '63/64']
# ['Frog:']
# ['Children:']
# ['My', 'oh', 'my,', 'what', 'a', 'wonderful', 'day.']
# ['Children:']
# ["headin'", 'my', 'way.']
# ['Chorus:']
# ['Mr.', "Bluebird's", 'on', 'my', 'shoulder.']
# ['Chorus:']
# ['Everything', 'is', 'satisfactual.']
# ['Chorus:']
# ['Oh', 'what', 'a', 'wonderful', 'feeling,']
# ['Chorus:']
# ['Singing', 'a', 'song,', 'a', 'Song', 'Of', 'The', 'South.']
# ['Page', '64/64']
# {'Music Chorus:': "music weaves a magic spell... Music I see the scenes I know so well... Music cabin door. Pale moon light on a field of white... Music Music That's where I belong. Singin' a song, a Song of the South Music That's how the critters got that way. Music That's what Uncle Remus said. Music     wake up early in the morning, when the ding dong ring, Music It's the same ol' thing, want to get a bite of something', Music look up, get yer' finger in the dumplin' Music Let the rain pour down. Let the cold win' blow, Music in the home I know. Music havin' trouble with de weevil, never did like that, Music like a hypocrite's hat, when the weevil git the cotton, Music there'll be nothin' on de table, Music Music meetin', how do you do, with everyone repeatin'... Music let the cold win' blow Music the misery, when your old and grey, Music playin' 'round yo door. faith in him. Music faith in him. Music faith in him. Music All I want... All I want... Music faith in him. Music  faith in him. Music faith in him. Music faith in him.",
#  'Music Solo:': "voices calling low. Out of the long, long ago. Music from eatin' too much speckle trout. Music  His bed was full of sandy lumps, Music Music He tried the same thing on a rail. Music  and the moon and the sun. Music Music Music on this little chil' Music",
# ...
#  'Johnny:': " like she did last spring?  at what Daddy writes in the newspaper. Don't she?          Please! I won't stay here! Johnny Crying Music    Just 'cause you said you would.     Brer Rabbit not coming back to his briar patch. that got away from the fox?        my hand, Uncle Remus, an' git a-goin.   Say 'knee-deep', Brer Frog, 'knee-deep', 'knee-deep'.  breakfast and get some more.  whispering to Toby Come on! Take him! Johnny giggles Frog ribbits     taking him back ain't frog huntin'! Toby 'Cose 'tain't! Come on!           Singing If I take you back, that Jack Favers'll drown you.   But it might be all right if... you kept him.        get away, Uncle Remus?  about Brer Frog havin' a tail...     You can tell aunt Tempy.... you can even tell my mama. don't tell your maw. that's all! If you do, it'll be awful! we s'posed to use our heads instead of our foots. Maw         Teenchy! Where are you? for Teenchy! Where's Teenchy? might happen to him... if he runs around loose.  my dog. He's mine. botherin' anybody. loves me. You should'na done it, Uncle Remus. him! I know he will. gone...and you don't care at all. you're...the best friend i have. Maw you were never comin'.  Play games, an'...get presents. does. Course, I get the most. attention to them, Ginny.      the party... if you wanta.  of an ol' party anyway. rabbit! Now let me see -- 'Bout this here brer rabbit... critter in the whole world. Anyway...    and Ginny's all ldirty. Please, Uncle Remus.   Let's start lookin.   Remus say so?  Uncle Remus, I've found it! It's right here... Uncle Remus is gone.   Uncle Remus!  Wait! Sally screams Uncle Remus! Come back!   Make him stay, please!  shoulder. It's the truth, It's actual. shoulder.",
#  'Sally:': " you'd enjoy seeing the plantation. What ever gave you that idea?   It wouldn't be fair to mama. I'm not going back.  and see if Johnny is with him.  but it's so long past Johnny's bedtime.  it's too late for him to be up. run along upstairs and get ready for bed. Toby and  Let's hurry up and get dressed. mother is coming to see us today.   You can go another day. and come on down to breakfast.   dog back to you. Now run along, please. Johnny to be obedient and truthful. But you and your it would be better if he didn't hear any more for awhile. not to tell him any more. can't just overlook it, he has to learn to mind. mother....and his grandmother.   And what happens then? little boys and girls. many other children, dear... write and ask him.  been doing? The party's all over, dear. to tell your guests goodbye.  couldn't stop telling your stories. Remus, but from now on from Johnny, you understand?     Music   place in the whole wide world.",
#  'John:': "    'em over in your grandma's milk house  He told me that story about Brer Frog. How can there be a tale... Tempy and  Have you changed your mind,  She's be only too glad to take care of Johnny. here for awhile... with you. And I want Sally to go with me. And I'd better hurry, or I'll miss my train.   to do, and you've got one too. You'll do that now for me, won't you?    Johnny!  I'm not going anywhere. where I belong.  than Brer Rabbit hisse'f. ",
#  'Tempy:': "Lissen! frogs like dem in Atlanta. you got for doin' it too.   him tell a tale 'bout Brer Rabbit.  Dat's jes' Ned. lis'nin to one 'o yo' tales?  home befo' yo' maw takes a stick after you? where he come from, jes' like yo' maw tol' you.  I betcha, I betcha that I getcha, you wait and see... be hangin' aroun'... I betcha... but sooner or later you're gonna be hanging aroun', Your gonna knock on my door, you don' it befo' cuz sooner or later I know you'll be hangingn aroun', But you ain't gonna get it. and totin' in three or four measley Some folks does de work, while others jest visits. like Brer Fox and Brer Rabbit. kitchen and we have Brer Rabbit stew. wool over my eyes. Here!  to take it right straight back what he got it. Ain't I done tol' you 'bout messin' 'roun' my kitchen?  suh, and' talkin' like his li'l heart's Mister John, he was cuttin' to stop Uncle Remus from goin' away. Music",
#  'Doshy:': " the house again. Turn around here, young man. grandfather more every time I see you. Toby! And he's the apple of my eye. you see that he gets out of it.  and what they're up to. clatter you've raised in Atlanta. and... heaven knows what. Perhaps I'd better show him myself. Come along.        doesn't count for much these days. But I'm afraid it's going to take  I'm a stubborn old woman Uncle Remus  Of course I'm not mad with you. Children laughing Uncle Remus and his stories, He needs something to hold on to. friends. And if it's not Uncle Remus, or the Favers someone of his own age. That's just good common sense. won't make any difference. ",
#  'Toby:': "   watch out!  de whole United States o' Georgia!  no place. An' I'se s'posed to take keer o'him.  fell in de mill pon'.. He mighter got et up. else! How you like dat, Unc' Remus! It's Him.        Remus'll let us use his frog box. gotter take Brer Frog back, ain't we? to get stomped on.. or runned over.. or lost. Like yo' miss yo' fambly. saw yo' maw or paw ag'in. we kin git dar a heap quicker. Here!      bad. An' if it's blowin' towards de bull, dat ain't good.          Unc' Remus, what you doin'? away! He's gettin' in de wagon! He got hurt by dat bull.",
#  'Ned:': 'Where do you want me to put dishyer trunk?',
#  'Chorus:': "Music Mr. Bluebird's on my shoulder. Everything is satisfactual. Oh what a wonderful feeling,",
#  'Solo:': 'Music Music Music Music',
#  'Chloe:': "Lawzy mursy, have you seen Johnny? high and low for dat child! Didn't Miss Doshy tell you to take care 'o him?  ",
#  'Tempe:': "Miss Sally go outer her min'.",
#  'Music Remus:': "my oh my, what a wonderful day. Music my way. Zip-a-dee-do-da, zip-a-dee-ay. Music It's de truff, it's actual, everything is satisfactual. Music wonderful feeling, wonderful day. Yass suh! Music my oh my what a wonderful day. Music It's de truff, it's actual, everything is satisfactual. Music zum, zum, zum, zum, zum, zum zum. Music bum, bum, bum, boo boo Boo Music It's de truff, it's actual... Music wonderful feeling, wonderful da... hammering noise",
#  'Music Moles:': 'Zip-a-dee-do-da, zip-a-dee-ay. Music',
#  'Bluebird:': 'Music',
#  'Rabbit:': "ol place like this! Doggone.. Keep on... Oh-ah-uh-uh-ah-hello Uncle Remus. goin' to be here. I'm goin' leave this 'ol place.    an' dis de place i belongs away from. there ain't gonna be no trouble. up my mind, an I ain't never comin' back.  ah can take care o' myself. Rabbit whistles as he hops away down the path Cowbel jingles as rabbit bounces   I'se makin' a dollar a minute. mighty fine scarecrow, brother Bear.   enough money! I gots all I wants.        Clip 'im in the head, Brother Bear.  howdy you and you howdy back, this for that and tit for tat.   an' so does the flea - i do what i like, an' i --   dat's what you axe me an' dat's what you knows.  Rabbit whistles Remus laughs   howdy! Is you hard o' hearin'? Ah said howdy! I counts three, i's goin' bus' you wide open!      I'll poke you ag'in ... lem-me go! go on, knock my head clean off.  Go ahead, but don't flong me dat briar patch.  go ahead. Heh heh, yes sir...skin me if ya likes, Brer Fox,  I mean...wa-wa-wa- whatever you do, Brer Fox... Brer Fox, please don't fling me in dat briar patch. fling me in dar, is ya? Rabbit makes dying sounds and bred in de briar patch. Laughs  I'se just been to my lauging place. about my laughing place, I can't help.  place I knows about. where it is when I'se all   place and yuk, yuk, yuk, yuk, yuk. And you'll find yours, I know, ho ho.   And you'll find yours, I know, ho ho. Wait a minute. There it is.   was you laughin' place. place Brer Bear. Rabbit Laughs Three them zip-a-dee-do-dah days. zip-a-dee-do-dah, zip-a-dee-ay.",
#  'Fox:': " rabbit dis time fo' sho'. Heh heh heh!      See there?     He's mine look out dar  come right now. Lem'me see, where was Gotta get a head right quick. Need about this much tar. 'bout right for a head. That biggity ol' rabbit We'll catch him sho'... i'll catch him sho'. Dey ain't nothin' smart 'bout dat! smartest is, an' de tar baby do de rest.  I'm glad i thought of that! let me see about this. Just 'bout this size. Oh, yes. A nose too... those very very badly. Got to have a nose. This is lookin' mo' natural all de time.  hep' me 'long, hep' me long, come on. coming down de road. Come on. any minute. Everythin' gotta' be just right. Now maybe if he had one ...  Hurry, hurry. Gotta get a move on. Come on!   I sho' hope ... it does ... ha ha!  Laughs    all stuck up in yo' swaller tail coat! I ain't never seen nobody look dat good befo'.   He forgot everything, didn't he Brer Bear? won't be long now ... dinner goin' be ready any a few more sticks on the fire. Yes ... is gwine stay fo' dinner, ain'cha', Brer Rabbit? Now, we jes' love to have you fo' dinner! Brer Bear? Ain't dat jes' what you been sayin'? Not that, no, no, not that. No wait! Let loose. You can't do that.  We're gonna make him suffer.  my little head I knowed what we gonna do.... 'Tain't none o' yo' business. Hang him by the neck til he's dead. so i'spects. I 'spects I'll have to skin ya.     I sho' am glad i thought of that!  No sir! We wouldn't do dat! Brer Bear? minute! Oh no, please don't! Look out, stop! There! trick on me, Brer Rabbit. played your last trick on me. mighty good in that bow-tie, Brer Rabbit. good in that bow-tie. bow-tie Brer Bear? dressed with a bow-tie befo'.  up for dinner. Fo my dinner. you dis very minute, on dat fire. Rabbit laughing Wait jes' a minute, Brer Rabbit. you... on dat fire! Now! laugh about? It's another one o' his tricks.   fire. I'm gonna...  this has gone far enough, this has gone far enough.   fool out of you, you fool.  as a laughing place.  go and have some...  out of yo'se'f this time. a fool outa yo'sef. ",
#  'Bear:': "Zip-da-da-da-da, wonderful day. Zip-a-da-de-da...                       gon' fool nobody ... it hain't got no eyes!  Rabbit whistling           I'm gonna... now jes' look....   I'm gonna knock his head clean off  We jes' gonna knock his head clean off.   laughing place? this laughing place at?   Rabbit singing         Bear yells here 'cept bees. was a laughin' place... ",
#  'Joe:': "  befo' I knock yo' head clean off.   Jake and   He told us not to tell our maw.     she giv'd us a whuppin'.  'tenshun to 'em, Ginny! ",
#  'Jake:': "   Look, Joe.     don't mean we ain't gonna git Teenchy.  or maybe even your maw.  He'll find out! Think's he so smart. jis' what he wanted us to do.   -- An' we we wants it back! ol' Remus's so's you wouldn't know.  care if we told you....        ",
#  'Ginny:': "  They was gonna drown 'im.    Don't you pay no 'tenshun to them. 'Cause maw says if I give 'im to you, he's yours. she'll whale the daylights out of 'um. Johnny laughs Maw The party'll be over. Maw Maw Maw  maw had an awful time finishing my dress. Like it? weddin' dress. Are we gonna have cake? party -- 'Sides have cake?     Ginny Crying Ginny Crying      a laughin' place ma'am? got one. Pleased to meetcha. laughing place?  tell 'im 'bout Brer Rabbit!",
#  'Singing Johnny:': "It's the truth, it's actual. Everything is satisfactual. Singing zip-a-dee-ay, wonderful feeling, wonderful day.",
#  'Butterflies:': '',
#  'Butterfly:': '',
#  'Possum:': ' ',
#  'Fish:': 'Rabbit whistles',
#  'Frog:': "you's headin' for trouble one o' these days. that ... oh thanks... put his foot in it one o' these days. ",
#  'Maw Favers:': "wanta hear no more 'bout it. Maw wants to give it away, 'tain't none o' yo' business.  and down I'll never get this collar on. what you says when you does it. looks pretty enough to go anywheres. forgit your manners.",
#  'Childern:': 'was bare! What time is it, old witch!',
#  'Jonnny:': 'Johnny, Ginny & Toby singing Zip-a-dee-do-dah, zip-a-dee-ay, Page 62/64',
#  'Three children:': 'Rabbit. Hi there, Brer Rabbit.',
#  'Children:': "day, plenty of sunshine headin' my way. zip-a-dee-ay. zip-a-dee-ay. wonderful day. my way, wonderful feeling, wondeful day. My oh my, what a wonderful day. headin' my way."}

# %%
for key,value in dic.items():
    print(key,len(value))
# Out:
# Music Chorus: 1027
# Music Solo: 253
# Remus: 6806
# Johnny: 1710
# Sally: 954
# John: 452
# Tempy: 901
# Doshy: 649
# Toby: 560
# Ned: 42
# Chorus: 93
# Solo: 23
# Chloe: 112
# Tempe: 29
# Music Remus: 453
# Music Moles: 36
# Bluebird: 5
# Rabbit: 1541
# Fox: 2049
# Bear: 372
# Joe: 135
# Jake: 248
# Ginny: 457
# Singing Johnny: 112
# Butterflies: 0
# Butterfly: 0
# Possum: 1
# Fish: 15
# Frog: 105
# Maw Favers: 216
# Childern: 37
# Jonnny: 71
# Three children: 30
# Children: 171

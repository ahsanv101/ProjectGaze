# %%
import os
import pandas as pd

cwd = os.getcwd()
print(cwd)

top_movies = cwd+'/Data/webscrape/movies.csv'

movies_df = pd.read_csv(top_movies,header=0)

bechdel_data=cwd+'/Data/bechdel/Bechdel_detailed.csv'
bechdel_df= pd.read_csv(bechdel_data)

# #import titles ds to match the by imdb id 
# title_name = cwd+'/datasets/title.basics.tsv'
# title_name_table= pd.read_csv(title_name, sep='\t', header=0, low_memory=False)


movies_df
bechdel_df.rename(columns={"title":"Title"}, inplace=True)
# Out:
# /Users/macuser/Desktop/infovizrepo/ProjectGaze

# %%
import re

#rename manually

bechdel_df.loc[bechdel_df['Title'].str.contains('Rogue One'), 'Title'] = bechdel_df['Title'].str.replace('Rogue One', 'Rogue One: A Star Wars Story')

bechdel_df.loc[bechdel_df['Title'].str.contains('Last Jedi'), 'Title'] = bechdel_df['Title'].str.replace('Star Wars: The Last Jedi', 'Star Wars: Episode VIII - The Last Jedi')

bechdel_df.loc[bechdel_df['Title'].str.fullmatch('Star Wars'), 'Title'] = bechdel_df['Title'].str.replace('Star Wars', 'Star Wars: Episode IV - A New Hope')


# FAILED FUNCTION FUCK
                                                                                                                    
# def rename_titles(df1, df2, common_str_list):
#     for common_str in common_str_list:
#         #first movies and second bechdel
#         df1_subset = df1[df1['Title'].str.contains(common_str)]
#         df2_subset = df2[df2['Title'].str.contains(common_str)]
        
#         #update df2 subset
#         title_map = dict(zip(df1_subset['Title'], df1_subset['Title'].str.extract(f'({common_str}.*)')[0]))

#         df2.loc[df2_subset.index, 'Title'] = df2_subset['Title'].replace(title_map)

        


#     return df2

# %%
#remove special characters etc
def normalize_string(s):
    s = s.replace('&#39;','')	
    s = s.replace("'", '')  # apostrophes with empty string
    s = re.sub(r'\W+', '', s)  # Remove non-alphanumeric 
    s = s.lower()  # Convert to lowercase
    s = s.replace(' ', '_') 
    s = s.replace('the', '')# Replace spaces with underscores
    s = s.replace('judgment', 'judgement')
    return s


bechdel_df['name_normalized'] = bechdel_df['Title'].apply(normalize_string)
movies_df['name_normalized'] = movies_df['Title'].apply(normalize_string)

# %%
final_df = pd.merge(bechdel_df, movies_df, on='name_normalized', how='right')
final_df
# Out:
#     Unnamed: 0                                       Title_x    year  rating  \
# 0        598.0                             Song of the South  1946.0     2.0
# 1          NaN                                           NaN     NaN     NaN
# 2        410.0                            Gone with the Wind  1939.0     3.0
# 3          NaN                                           NaN     NaN     NaN
# 4          NaN                                           NaN     NaN     NaN
# ..         ...                                           ...     ...     ...
# 80      5534.0                                        Avatar  2009.0     3.0
# 81      6970.0                                  Man of Steel  2013.0     3.0
# 82      8194.0                  Rogue One: A Star Wars Story  2016.0     3.0
# 83      6233.0  Harry Potter and the Deathly Hallows: Part 2  2011.0     3.0
# 84      7387.0                    X-Men: Days of Future Past  2014.0     1.0
#
#     dubious     imdbid      id  submitterid                 date  visible  \
# 0       0.0    38969.0  5646.0      10566.0  2014-07-22 21:06:00      1.0
# 1       NaN        NaN     NaN          NaN                  NaN      NaN
# 2       NaN    31381.0   291.0         28.0  2009-03-02 14:31:54      1.0
# 3       NaN        NaN     NaN          NaN                  NaN      NaN
# 4       NaN        NaN     NaN          NaN                  NaN      NaN
# ..      ...        ...     ...          ...                  ...      ...
# 80      0.0   499549.0   582.0        312.0  2009-12-22 23:33:32      1.0
# 81      0.0   770828.0  4238.0       7387.0  2013-06-13 06:26:13      1.0
# 82      0.0  3748528.0  7334.0      14317.0  2016-12-16 20:12:38      1.0
# 83      1.0  1201607.0  2539.0       3773.0  2011-07-14 20:35:38      1.0
# 84      0.0  1877832.0  5499.0      10196.0  2014-05-25 02:37:10      1.0
#
#                       name_normalized  \
# 0                         songofsouth
# 1                    samsonanddelilah
# 2                        gonewithwind
# 3                       bellsofstmary
# 4                        sergeantyork
# ..                                ...
# 80                             avatar
# 81                         manofsteel
# 82             rogueoneastarwarsstory
# 83  harrypotteranddeathlyhallowspart2
# 84               xmendaysoffuturepast
#
#                                          Title_y Decade       Genre  \
# 0                              Song of the South    40s   Animation
# 1                             Samson and Delilah    40s  Historical
# 2                             Gone with the Wind    40s       Drama
# 3                          The Bells of St. Mary    40s     Musical
# 4                                  Sergeant York    40s         War
# ..                                           ...    ...         ...
# 80                                        Avatar  2010s      SCI-FI
# 81                                  Man of Steel  2010s      Action
# 82                  Rogue One: A Star Wars Story  2010s      SCI-FI
# 83  Harry Potter and the Deathly Hallows: Part 2  2010s     Fantasy
# 84                    X-Men: Days of Future Past  2010s      Action
#
#                          Director  \
# 0   Wilfred Jackson, Harve Foster
# 1                 Cecil B.DeMille
# 2                  Victor Fleming
# 3                     Leo McCarey
# 4                     Leo McCarey
# ..                            ...
# 80                  James Cameron
# 81                    Zack Snyder
# 82                 Gareth Edwards
# 83                    David Yates
# 84                   Bryan Singer
#
#                                               Reviews
# 0   https://www.imdb.com/title/tt0038969/reviews?r...
# 1   https://www.imdb.com/title/tt0041838/reviews?r...
# 2   https://www.imdb.com/title/tt0031381/reviews?r...
# 3   https://www.imdb.com/title/tt0037536/reviews?r...
# 4   https://www.imdb.com/title/tt0034167/reviews?r...
# ..                                                ...
# 80  https://www.imdb.com/title/tt0499549/reviews?r...
# 81  https://www.imdb.com/title/tt0770828/reviews?r...
# 82  https://www.imdb.com/title/tt3748528/reviews?r...
# 83  https://www.imdb.com/title/tt1201607/reviews?r...
# 84  https://www.imdb.com/title/tt1877832/reviews?r...
#
# [85 rows x 16 columns]

# %%
#study missing values

null_values_x= final_df['Title_x'].isna()
null_values_x.sum()
final_df[null_values_x]

bechdel_no_data= final_df[null_values_x]
bechdel_no_data = bechdel_no_data.drop(["Unnamed: 0","name_normalized"], axis=1)
bechdel_no_data = bechdel_no_data.dropna(axis=1)
bechdel_no_data.rename(columns={"Title_y":"Title"}, inplace= True)
bechdel_no_data.reset_index(drop=True, inplace=True)
bechdel_no_data.to_csv
# Out:
# <bound method NDFrame.to_csv of                    Title Decade       Genre                       Director  \
# 0     Samson and Delilah    40s  Historical                Cecil B.DeMille
# 1  The Bells of St. Mary    40s     Musical                    Leo McCarey
# 2          Sergeant York    40s         War                    Leo McCarey
# 3           Going My Way    40s     Musical                   Howard Hawks
# 4          Forever Amber    40s       Drama  John M. Stahl, Otto Preminger
# 5    Yankee Doodle Dandy    40s     Musical                 Michael Curtiz
# 6          The Sea Chase    50s         War                    John Farrow
# 7              The Bible    60s  Historical                    John Huston
# 8    Fiddler on the Roof    70s     Musical                 Norman Jewison
#
#                                              Reviews
# 0  https://www.imdb.com/title/tt0041838/reviews?r...
# 1  https://www.imdb.com/title/tt0037536/reviews?r...
# 2  https://www.imdb.com/title/tt0034167/reviews?r...
# 3  https://www.imdb.com/title/tt0036872/reviews?r...
# 4  https://www.imdb.com/title/tt0039391/reviews?r...
# 5  https://www.imdb.com/title/tt0035575/reviews?r...
# 6  https://www.imdb.com/title/tt0048593/reviews?r...
# 7  https://www.imdb.com/title/tt0060164/?ref_=nv_...
# 8  https://www.imdb.com/title/tt0067093/reviews?r...  >

# %%
movies_bechdel = final_df.drop(['Unnamed: 0','submitterid','date','name_normalized', 'id','visible','Title_x'],axis=1)
movies_bechdel.rename(columns={"Title_y":"Title","rating":"bechdel_rating"}, inplace= True)
movies_bechdel = movies_bechdel[['imdbid','Title', 'Decade', 'Genre', 'Director', 'year', 'bechdel_rating', 'dubious']]

title_duplicates = movies_bechdel[movies_bechdel['Title'].duplicated(keep=False)]
# title_duplicates
#drop duplicates by their index
movies_bechdel= movies_bechdel.drop([24,25,29,77])
movies_bechdel.reset_index(drop=True, inplace=True)
# movies_bechdel[movies_bechdel['Title'].duplicated(keep=False)]
movies_bechdel.to_csv(cwd+'/Data/bechdel/all_movies_bechdel.csv')

movies_bechdel
# Out:
#        imdbid                                         Title Decade  \
# 0     38969.0                             Song of the South    40s
# 1         NaN                            Samson and Delilah    40s
# 2     31381.0                            Gone with the Wind    40s
# 3         NaN                         The Bells of St. Mary    40s
# 4         NaN                                 Sergeant York    40s
# ..        ...                                           ...    ...
# 76   499549.0                                        Avatar  2010s
# 77   770828.0                                  Man of Steel  2010s
# 78  3748528.0                  Rogue One: A Star Wars Story  2010s
# 79  1201607.0  Harry Potter and the Deathly Hallows: Part 2  2010s
# 80  1877832.0                    X-Men: Days of Future Past  2010s
#
#          Genre                       Director    year  bechdel_rating  dubious
# 0    Animation  Wilfred Jackson, Harve Foster  1946.0             2.0      0.0
# 1   Historical                Cecil B.DeMille     NaN             NaN      NaN
# 2        Drama                 Victor Fleming  1939.0             3.0      NaN
# 3      Musical                    Leo McCarey     NaN             NaN      NaN
# 4          War                    Leo McCarey     NaN             NaN      NaN
# ..         ...                            ...     ...             ...      ...
# 76      SCI-FI                  James Cameron  2009.0             3.0      0.0
# 77      Action                    Zack Snyder  2013.0             3.0      0.0
# 78      SCI-FI                 Gareth Edwards  2016.0             3.0      0.0
# 79     Fantasy                    David Yates  2011.0             3.0      1.0
# 80      Action                   Bryan Singer  2014.0             1.0      0.0
#
# [81 rows x 8 columns]

# %%
#no two female characters scene
no_two_females = movies_bechdel[movies_bechdel["bechdel_rating"] == 0.0]
no_two_females.reset_index(drop=True, inplace=True)
no_two_females.to_csv(cwd+'/Data/bechdel/bechdel_failed_0.csv')

#no two females talking
no_talking = movies_bechdel[movies_bechdel["bechdel_rating"] == 1.0]
no_talking.reset_index(drop=True, inplace=True)
no_talking.to_csv(cwd+'/Data/bechdel/bechdel_failed_1.csv')

#two females, but talking about a man

talking_about_male = movies_bechdel[movies_bechdel["bechdel_rating"] == 2.0]
talking_about_male.reset_index(drop=True, inplace=True)
talking_about_male.to_csv(cwd+'/Data/bechdel/bechdel_failed_2.csv')
#passed the bechdel test :)
bechdel_passed = movies_bechdel[movies_bechdel["bechdel_rating"] == 3.0] 
bechdel_passed.reset_index(drop=True, inplace=True)
bechdel_passed.to_csv(cwd+'/Data/bechdel/bechdel_passed.csv')

"No more than one female character:", no_two_females['Title'], "Two female characters, but they do not talk to eachother:", no_talking['Title'], "Two female characters talking about a man:", talking_about_male['Title'], "Passed the bechdel test:", bechdel_passed['Title']
# Out:
# ('No more than one female character:',
#  0                             2001: A Space Odyssey
#  1                                Lawrence of Arabia
#  2    Star Wars: Episode V - The Empire Strikes Back
#  3                                    Batman Returns
#  4                             Mission Impossible II
#  Name: Title, dtype: object,
#  'Two female characters, but they do not talk to eachother:',
#  0                                       Casablanca
#  1                     The Bridge on the River Kwai
#  2               Butch Cassidy and the Sundance Kid
#  3               Star Wars: Episode IV - A New Hope
#  4                                  Blazing Saddles
#  5                                            Rocky
#  6                                       Love Story
#  7                                         Superman
#  8                                           Batman
#  9       Star Wars: Episode VI - Return of the Jedi
#  10                            Beverly Hills Cop II
#  11                         Who Framed Roger Rabbit
#  12                                    Forrest Gump
#  13                                    Men in Black
#  14                                  Batman Forever
#  15                                       Spiderman
#  16    Star Wars: Episode III - Revenge of the Sith
#  17                                    Spider-Man 2
#  18                                    The Avengers
#  19                      X-Men: Days of Future Past
#  Name: Title, dtype: object,
#  'Two female characters talking about a man:',
#  0                            Song of the South
#  1                         The Ten Commandments
#  2                   The Greatest Show on Earth
#  3                                 The Graduate
#  4                                The Godfather
#  5                                 Ghostbusters
#  6                           Back to the Future
#  7                                      Top Gun
#  8    Pirates of the Caribbean: Dead Mans Chest
#  Name: Title, dtype: object,
#  'Passed the bechdel test:',
#  0                                    Gone with the Wind
#  1                                         The Snake Pit
#  2                                 From Here To Eternity
#  3                                       White Christmas
#  4                                            Quo Vadis?
#  5                                 Cat on a Hot Tin Roof
#  6                                      Some like it hot
#  7                                         All About Eve
#  8                                    The Sound of Music
#  9                                          Mary Poppins
#  10                                            Cleopatra
#  11                                      West Side Story
#  12                                               Psycho
#  13                                                 JAWS
#  14                                         The Exorcist
#  15                                               Grease
#  16                           E.T. the Extra-Terrestrial
#  17                                         Ghostbusters
#  18                                          Superman II
#  19                                              Titanic
#  20            Star Wars: Episode I - The Phantom Menace
#  21                                        Jurassic Park
#  22                                     Independence Day
#  23                                                Ghost
#  24                           Terminator 2: Judgment Day
#  25                                      The Dark Knight
#  26              Harry Potter and the Half Blood Prince
#  27                                         Transformers
#  28    Pirates of the Caribbean: The Curse of the Bla...
#  29                 Harry Potter and the Sorcerers Stone
#  30                                    Avengers: Endgame
#  31                                        Black Panther
#  32                         Star Wars: The Force Awakens
#  33              Star Wars: Episode VIII - The Last Jedi
#  34                                               Avatar
#  35                                         Man of Steel
#  36                         Rogue One: A Star Wars Story
#  37         Harry Potter and the Deathly Hallows: Part 2
#  Name: Title, dtype: object)
